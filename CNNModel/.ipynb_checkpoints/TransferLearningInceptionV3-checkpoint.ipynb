# %%
import tensorflow as tf
from tensorflow.contrib.framework.python.ops.variables import get_or_create_global_step
from tensorflow.python.platform import tf_logging as logging
import inception_preprocessing
from inception_resnet_v2 import inception_resnet_v2, inception_resnet_v2_arg_scope
import os
import time
slim = tf.contrib.slim
# Out:
# WARNING:tensorflow:From d:\programs\anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# # Dataset Information
# ### State dataset directory where the TFRecord files are located

# %%
dataset_dir = 'data'

# State where ur log file is at. If it doesn't exist, create it
log_dir = 'log'

#State where your checkpoint file is
checkpoint_file = 'doc/inception_resnet_v2_2016_08_30.ckpt'

#State the image size you're resizing your images to. We will use the default inception size of 299.
image_size = 299

#State the num of classes to predict
num_classes = 5

#State the labels file and read
label_file = 'data/labels.txt'
labels = open(label_file, 'r')

# Create a dictionary to refer each label to their string name
labels_to_name = {}
for line in labels:
    label, string_name = line.split(':')
    print(label)
    string_name = string_name[:-1] # Remove newline
    labels_to_name[int(label)] = string_name

#Create the file pattern of your 
#TFRecord files so that it could be recognized later on
file_pattern = 'flower_%s_*.tfrecord'

items_to_descriptions = {
    'image': 'A 3-channel RGB coloured flower image that is either tulips, sunflowers, roses, dandelion, or daisy.',
    'label': 'A label that is as such -- 0:daisy, 1:dandelion, 2:roses, 3:sunflowers, 4:tulips'
}
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Training

# %%
num_epochs = 70
batch_size = 10

#Learning rate information and configuration (Up to you to experiment)
initial_learning_rate = 0.0002
learning_rate_decay_factor = 0.7
num_epochs_before_decay = 2

# %% [markdown]
# # Creating A DataSet Object

# %%
'''INPUTS:
    - split_name(str): 'train' or 'validation'. Used to get the correct data split of tfrecord files
    - dataset_dir(str): the dataset directory where the tfrecord files are located
    - file_pattern(str): the file name structure of the tfrecord files in order to get the correct data
    - file_pattern_for_counting(str): the string name to identify your tfrecord files for counting
    OUTPUTS:
    - dataset (Dataset): A Dataset class object where we can read its various components for easier batch creation later.'''
    
        
def get_split(split_name, dataset_dir, file_pattern=file_pattern, file_pattern_for_counting='flower'):
    #First check whether the split_name is train or validation
    if split_name not in ['train', 'validation']:
        raise ValueError('The split_name %s is bit recognized.\
                        Please input either train or validation\
                        as the split_name' % (split_name))
    
    #Create the full path for a general file_pattern to locate the tfrecord_files.
    file_pattern_path = os.path.join(dataset_dir, 
                                     file_pattern % (split_name))
    
    # Count the total number of examples in all of these shard
    num_samples = 0
    file_pattern_for_counting = file_pattern_for_counting  + '_' + split_name
    tfrecords_to_count = [os.path.join(dataset_dir, file) for file in os.listdir(dataset_dir) if file.startswith(file_pattern_for_counting)]
    
    for tfrecord_file in tfrecords_to_count:
        for record in tf.python_io.tf_record_iterator(tfrecord_file):
            num_samples += 1
    
    # Create a reader , which must be a TFRecord reader in this case
    reader = tf.TFRecordReader
    
    #Create the keys_to_features dictionary for the decoder
    key_to_features = {
        'image/encoded': tf.FixedLenFeature((), tf.string, default_value=''),
        'image/format': tf.FixedLenFeature((), tf.string, default_value='jpg'),
        'image/class/label': tf.FixedLenFeature(
            [], tf.int64, default_value=tf.zeros([], dtype=tf.int64)),
    }
    
    #Create the items_to_handlers dictionary for the decoder
    items_to_handlers = {
        'image': slim.tfexample_decoder.Image(),
        'label': slim.tfexample_decoder.Tensor('image/class/label'),
    }
    
    # Start to create the decoder
    decoder = slim.tfexample_decoder.TFExampleDecoder(key_to_features, items_to_handlers)
    
    # Create the labels to name file
    labels_to_name_dict = labels_to_name
    
    # Actually create the dataset
    dataset = slim.dataset.Dataset(
            data_sources= file_pattern_path,
            decoder= decoder,
            reader= reader,
            num_reader = 4,
            num_samples = num_samples,
            num_classes = num_classes,
            labels_to_name= labels_to_name_dict,
            items_to_descriptions= items_to_descriptions
    )
    
    return dataset

# %% [markdown]
# # Functions
# - tf.expand_dims will expand the 3D tensor from a [height, width, channels] shape to [1, height, width, channels] shape
#
#
# - tf.squeeze will simply eliminate all the dimensions with the number ‘1’, which brings the raw_image back to the same 3D shape after reshaping.

# %%
def load_batch(dataset, batch_size, height=image_size, width=image_size, is_training=True):
    '''
    Loads a batch for training.
    INPUTS:
    - dataset(Dataset): a Dataset class object that is created from the get_split function
    - batch_size(int): determines how big of a batch to train
    - height(int): the height of the image to resize to during preprocessing
    - width(int): the width of the image to resize to during preprocessing
    - is_training(bool): to determine whether to perform a training or evaluation preprocessing
    OUTPUTS:
    - images(Tensor): a Tensor of the shape (batch_size, height, width, channels) that contain one batch of images
    - labels(Tensor): the batch's labels with the shape (batch_size,) (requires one_hot_encoding).
    '''
    
    # Create the data Provider object
    data_provider = slim.dataset_data_provider.DatasetDataProvider(
                dataset,
                common_queue_capacity= 24 + 3 * batch_size,
                common_queue_min = 24)
    
    #obtain the raw image using the get method
    raw_image, label = data_provider.get(['image','label'])
    
    #Perform the correct preprocessing for this image depending if it is training or evaluating
    image = inception_preprocessing.preprocess_image(raw_image, height, width, is_training)
    
    #As for the raw images, we just do a simple reshape to batch it up
    raw_image = tf.expand_dims(raw_image, 0)
    raw_image = tf.image.resize_nearest_neighbor(raw_image, [height,width])
    
    #Batch up the image by enqueing the tensors internally in a FIFO queue and dequeueing many elements with tf.train.batch.
    images, raw_image, labels = tf.train.batch(
                    [image, raw_image, label],
                    batch_size = batch_size,
                    num_threads = 4,
                    capacity = 3 * batch_size,
                    allow_smaller_final_batch = True)
    
    return images, raw_image, labels

# %% [markdown]
# # TRAINING PROCESS
#
# ### Logits Layer
#
# 更にもう一度 tf.layers.dense を呼び出すことにより出力層を定義します、今回は活性化関数なしでです :
#
# 1. Compute logits (1 per class).
# 2. logits = tf.layers.dense(net, params['n_classes'], activation=None)
#
# ここで、net は最後の隠れ層を表します。従って、層の完全な層は今では次のように接続されています :
#
#
# ![title](Imagedoc/logits.png)
#
#
# 出力層を定義するとき、units パラメータは出力の数を指定します。それで、units を params[‘n_classes’] に設定することで、モデルはクラス毎に一つの出力値を生成します。出力ベクトルの各要素は、それぞれアイリスの関連するクラス: セトサ, バージカラー, バージニカのために計算された、スコア、あるいは「ロジット」を含むでしょう。
#
# 後で、これらのロジットは tf.nn.softmax 関数により確率へと変換されるでしょう。
#
#
# ### Speed up during the training
#
# - To increase the speed, one way is to also stop calling the summaries so often every 10 steps. Maybe calling summaries every 30 steps is a good interval as well

# %%
def run():
    #Create the log directory here. Must be done here otherwise import will activate this unneededly.
    if not os.path.exists(log_dir):
        os.mkdir(log_dir)
    
    #Now we start to construct the graph and build our model
    with tf.Graph().as_default() as graphs:
        # Set the verbosity to INFO level
        tf.logging.set_verbosity(tf.logging.INFO)
        
        # First create the dataset and load one batch
        dataset = get_split('train', dataset_dir, file_pattern)
        images, _, labels = load_batch(dataset, batch_size=batch_size)
        
        # Know the num steps to take before decaying the learning rate and batches per epoch
        num_batches_per_epoch = int(dataset.num_samples / batch_size)
        # One step is one batch processed
        num_steps_per_epoch = num_batches_per_epoch
        decay_steps = int(num_epochs_before_decay * num_steps_per_epoch)
        
        #create the model inference
        with slim.arg_scope(inception_resnet_v2_arg_scope()):
            logits, end_points = inception_resnet_v2(images, num_classes=dataset.num_classes,is_training=True)
            
        # Define the scopes that want to exclude for restoration
        exclude = ['InceptionResnetV2/Logits', 'InceptionResnetV2/AuxLogits']
        variables_to_restore = slim.get_variables_to_restore(exclude = exclude)
        
        #Perform one-hot-encoding of the labels (Try one-hot-encoding within the load_batch function!)
        one_hot_labels = slim.one_hot_encoding(labels, dataset.num_classes)
        
        #Performs the equivalent to tf.nn.sparse_softmax_cross_entropy_with_logits but enhanced with checks
        loss = tf.losses.softmax_cross_entropy(onehot_labels = one_hot_labels, logits = logits)
        #obtain the regularization losses as well
        total_loss = tf.losses.get_total_loss()
        
        #Create the global step for monitoring the learning rate and training
        global_step = get_or_create_global_step()
        
        #Define your exponentially decaying learning rate
        lr = tf.train.exponential_decay(
            learning_rate = initial_learning_rate,
            global_step = global_step,
            decay_steps = decay_steps,
            decay_rate = learning_rate_decay_factor,
            staircase = True)
        
        
        #Now we can define the optimizer that takes on the learning rate
        optimizer = tf.train.AdamOptimizer(learning_rate=lr)
        
        #Create the train_op
        train_op = slim.learning.create_train_op(total_loss, optimizer)
        
        #State the metrics that you want to predict.
        #We get a predictions that is not one_hot_encoded.
        predictions = tf.arg_max(end_points['Predictions'], 1)
        probabilities = end_points['Predictions']                                    
        accuracy, accuracy_update = tf.contrib.metrics.streaming_accuracy(predictions, labels)
        metrics_op = tf.group(accuracy_update, probabilities)
        
        
        #Now finally create all the summaries you need 
        # to monitor and group them into one summary op.
        tf.summary.scalar('losses/Total_Loss', total_loss)
        tf.summary.scalar('accuracy', accuracy)
        tf.summary.scalar('learning_rate', lr)
        my_summary_op = tf.summary.merge_all()
        
        #Now we need to create a training step function that 
        #runs both the train_op, metrics_op and updates the global_step concurrently.
        def train_step(sess, train_op, global_step):
            '''
            Simply runs a session for the three arguments provided and gives a logging on the time elapsed for each global step
            '''
            #Check the time for each sess run
            start_time = time.time()
            total_loss, global_step_count, _ = sess.run([train_op, global_step, metrics_op])
            tim_elapsed = time.time() - start_time
            
            #Run the logging to print some results
            logging.info('global step %s: loss: %.4f (%.2f sec/step)', global_step_count, total_loss, tim_elapsed)

            return total_loss, global_step_count
        
        #Now we create a saver function that actually restores 
        #the variables from a checkpoint file in a sess
        saver = tf.train.Saver(variables_to_restore)
        def restore_fn(sess):
            return saver.restore(sess, checkpoint_file)
        
        #Define your supervisor for running a managed session. 
        #Do not run the summary_op automatically or else it will consume too much memory
        sv = tf.train.Supervisor(logdir = log_dir, summary_op = None, init_fn = restore_fn)
        
        
        #Run the managed session
        with sv.managed_session() as sess:
            for step in range(num_steps_per_epoch * num_epochs): 
                #At the start of every epoch, show the vital information:
                if step % num_batches_per_epoch == 0:
                    logging.info('Epoch %s/%s', step/num_batches_per_epoch + 1, num_epochs)
                    learning_rate_value, accuracy_value = sess.run([lr, accuracy])
                    logging.info('Current Learning Rate: %s', learning_rate_value)
                    logging.info('Current Streaming Accuracy: %s', accuracy_value)

                    # optionally, print your logits and predictions for a sanity check that things are going fine.
                    logits_value, probabilities_value, predictions_value, labels_value = sess.run([logits, probabilities, predictions, labels])
                    print ('logits: \n', logits_value)
                    print ('Probabilities: \n', probabilities_value)
                    print ('predictions: \n', predictions_value)
                    print ('Labels:\n:', labels_value)

                #Log the summaries every 10 step.
                if step % 10 == 0:
                    loss, _ = train_step(sess, train_op, sv.global_step)
                    summaries = sess.run(my_summary_op)
                    sv.summary_computed(sess, summaries)
                    
                #If not, simply run the training step
                else:
                    loss, _ = train_step(sess, train_op, sv.global_step)

            #We log the final training loss and accuracy
            logging.info('Final Loss: %s', loss)
            logging.info('Final Accuracy: %s', sess.run(accuracy))

            #Once all the training has been done, save the log files and checkpoint model
            logging.info('Finished training! Saving model to disk now.')
            # saver.save(sess, "./flowers_model.ckpt")
            sv.saver.save(sess, sv.save_path, global_step = sv.global_step)

# %%
run()
# Out:
# INFO:tensorflow:Restoring parameters from log\model.ckpt-0
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Saving checkpoint to path log\model.ckpt
# INFO:tensorflow:global_step/sec: 0
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:Epoch 1.0/70
# INFO:tensorflow:Current Learning Rate: 0.0002
# INFO:tensorflow:Current Streaming Accuracy: 0.0
# logits:
#  [[-0.20001651 -0.063891   -0.29900855 -0.01182333  0.32637012]
#  [ 0.341255    0.62220204  0.5052881  -0.05117088  1.5382984 ]
#  [ 0.10361114 -0.35423183  0.1463519  -0.327596    0.50012386]
#  [ 0.24521779  0.0336927   0.4779879   0.5187997   0.8923482 ]
#  [-0.36527514  0.14260456  0.1019668   0.23693207  0.66063637]
#  [-0.22619832  0.32535726  0.11475125  0.2131368   0.42736343]
#  [ 0.6446673  -0.09917943  0.07179455 -0.08954465  0.8387275 ]
#  [-0.09634104  0.22586419 -0.9729515  -0.35852203  1.0413126 ]
#  [ 0.23357472  0.17919202 -0.34465683 -0.3904922   1.5040972 ]
#  [ 0.14047317  0.26394278  0.01805195 -1.3998065   0.8686694 ]]
# Probabilities:
#  [[0.16802637 0.19252895 0.15218988 0.20281903 0.2844358 ]
#  [0.13354042 0.17685874 0.15734448 0.0901954  0.44206092]
#  [0.20778489 0.13145444 0.2168583  0.1350029  0.30889952]
#  [0.15882702 0.12854649 0.2004542  0.20880434 0.30336785]
#  [0.11269975 0.18728039 0.1798223  0.20580609 0.3143914 ]
#  [0.13129762 0.22792627 0.18464151 0.20373125 0.25240335]
#  [0.267864   0.12731095 0.15104933 0.1285435  0.3252322 ]
#  [0.14958483 0.20645216 0.06225588 0.11508632 0.4666209 ]
#  [0.15136759 0.14335565 0.08490048 0.08109687 0.5392794 ]
#  [0.18861328 0.21340002 0.16688043 0.04042381 0.39068243]]
# predictions:
#  [4 4 4 4 4 4 4 4 4 4]
# Labels:
# : [4 1 4 3 0 4 1 2 1 1]
# INFO:tensorflow:global step 0: loss: 2.3063 (9.32 sec/step)
# INFO:tensorflow:global step 1: loss: 2.0754 (0.67 sec/step)
# INFO:tensorflow:global step 2: loss: 1.7881 (0.68 sec/step)
# INFO:tensorflow:global step 3: loss: 1.9888 (0.68 sec/step)
# INFO:tensorflow:global step 4: loss: 1.8261 (0.69 sec/step)
# INFO:tensorflow:global step 5: loss: 1.5493 (0.69 sec/step)
# INFO:tensorflow:global step 6: loss: 1.7858 (0.68 sec/step)
# INFO:tensorflow:global step 7: loss: 1.1296 (0.69 sec/step)
# INFO:tensorflow:global step 8: loss: 0.9682 (0.68 sec/step)
# INFO:tensorflow:global step 9: loss: 2.0289 (0.69 sec/step)
# INFO:tensorflow:global step 10: loss: 1.4764 (0.68 sec/step)
# INFO:tensorflow:global step 11: loss: 1.7121 (0.67 sec/step)
# INFO:tensorflow:global step 12: loss: 0.9789 (0.71 sec/step)
# INFO:tensorflow:global step 13: loss: 1.3408 (0.70 sec/step)
# INFO:tensorflow:global step 14: loss: 1.4930 (0.68 sec/step)
# INFO:tensorflow:global step 15: loss: 1.2572 (0.69 sec/step)
# INFO:tensorflow:global step 16: loss: 1.1194 (0.69 sec/step)
# INFO:tensorflow:global step 17: loss: 1.1147 (0.68 sec/step)
# INFO:tensorflow:global step 18: loss: 1.1119 (0.69 sec/step)
# INFO:tensorflow:global step 19: loss: 1.3927 (0.69 sec/step)
# INFO:tensorflow:global step 20: loss: 0.8695 (0.70 sec/step)
# INFO:tensorflow:global step 21: loss: 0.8945 (0.68 sec/step)
# INFO:tensorflow:global step 22: loss: 1.8423 (0.71 sec/step)
# INFO:tensorflow:global step 23: loss: 1.9589 (0.68 sec/step)
# INFO:tensorflow:global step 24: loss: 1.6989 (0.69 sec/step)
# INFO:tensorflow:global step 25: loss: 1.7102 (0.69 sec/step)
# INFO:tensorflow:global step 26: loss: 1.8719 (0.69 sec/step)
# INFO:tensorflow:global step 27: loss: 1.9287 (0.69 sec/step)
# INFO:tensorflow:global step 28: loss: 1.7665 (0.69 sec/step)
# INFO:tensorflow:global step 29: loss: 1.8852 (0.69 sec/step)
# INFO:tensorflow:global step 30: loss: 1.5461 (0.69 sec/step)
# INFO:tensorflow:global step 31: loss: 1.5400 (0.68 sec/step)
# INFO:tensorflow:global step 32: loss: 1.9237 (0.69 sec/step)
# INFO:tensorflow:global step 33: loss: 1.6399 (0.67 sec/step)
# INFO:tensorflow:global step 34: loss: 2.1853 (0.67 sec/step)
# INFO:tensorflow:global step 35: loss: 1.6138 (0.69 sec/step)
# INFO:tensorflow:global step 36: loss: 1.6352 (0.71 sec/step)
# INFO:tensorflow:global step 37: loss: 1.2666 (0.69 sec/step)
# INFO:tensorflow:global step 38: loss: 1.4908 (0.69 sec/step)
# INFO:tensorflow:global step 39: loss: 1.6101 (0.68 sec/step)
# INFO:tensorflow:global step 40: loss: 1.3794 (0.68 sec/step)
# INFO:tensorflow:global step 41: loss: 1.2718 (0.69 sec/step)
# INFO:tensorflow:global step 42: loss: 1.3098 (0.70 sec/step)
# INFO:tensorflow:global step 43: loss: 1.5695 (0.69 sec/step)
# INFO:tensorflow:global step 44: loss: 1.5388 (0.68 sec/step)
# INFO:tensorflow:global step 45: loss: 1.3676 (0.70 sec/step)
# INFO:tensorflow:global step 46: loss: 1.0035 (0.68 sec/step)
# INFO:tensorflow:global step 47: loss: 1.2122 (0.68 sec/step)
# INFO:tensorflow:global step 48: loss: 0.8355 (0.71 sec/step)
# INFO:tensorflow:global step 49: loss: 1.6736 (0.69 sec/step)
# INFO:tensorflow:global step 50: loss: 0.9642 (0.68 sec/step)
# INFO:tensorflow:global step 51: loss: 1.3621 (0.71 sec/step)
# INFO:tensorflow:global step 52: loss: 1.3624 (0.69 sec/step)
# INFO:tensorflow:global step 53: loss: 0.8980 (0.68 sec/step)
# INFO:tensorflow:global step 54: loss: 1.2680 (0.69 sec/step)
# INFO:tensorflow:global step 55: loss: 0.8190 (0.71 sec/step)
# INFO:tensorflow:global step 56: loss: 1.3276 (0.69 sec/step)
# INFO:tensorflow:global step 57: loss: 1.3641 (0.68 sec/step)
# INFO:tensorflow:global step 58: loss: 1.3770 (0.68 sec/step)
# INFO:tensorflow:global step 59: loss: 1.5638 (0.70 sec/step)
# INFO:tensorflow:global step 60: loss: 1.3627 (0.69 sec/step)
# INFO:tensorflow:global step 61: loss: 1.1960 (0.72 sec/step)
# INFO:tensorflow:global step 62: loss: 0.6232 (0.68 sec/step)
# INFO:tensorflow:global step 63: loss: 0.8335 (0.71 sec/step)
# INFO:tensorflow:global step 64: loss: 0.9268 (0.71 sec/step)
# INFO:tensorflow:global step 65: loss: 1.1557 (0.70 sec/step)
# INFO:tensorflow:global step 66: loss: 1.1953 (0.69 sec/step)
# INFO:tensorflow:global step 67: loss: 1.3448 (0.69 sec/step)
# INFO:tensorflow:global step 68: loss: 1.1259 (0.68 sec/step)
# INFO:tensorflow:global step 69: loss: 0.8552 (0.69 sec/step)
# INFO:tensorflow:global step 70: loss: 0.8468 (0.68 sec/step)
# INFO:tensorflow:global step 71: loss: 0.7310 (0.68 sec/step)
# INFO:tensorflow:global step 72: loss: 0.7308 (0.68 sec/step)
# INFO:tensorflow:global step 73: loss: 1.5103 (0.69 sec/step)
# INFO:tensorflow:global step 74: loss: 1.9109 (0.70 sec/step)
# INFO:tensorflow:global step 75: loss: 0.8443 (0.67 sec/step)
# INFO:tensorflow:global step 76: loss: 0.6170 (0.69 sec/step)
# INFO:tensorflow:global step 77: loss: 1.2258 (0.69 sec/step)
# INFO:tensorflow:global step 78: loss: 1.1562 (0.71 sec/step)
# INFO:tensorflow:global step 79: loss: 1.2770 (0.68 sec/step)
# INFO:tensorflow:global step 80: loss: 1.1247 (0.70 sec/step)
# INFO:tensorflow:global step 81: loss: 1.1144 (0.68 sec/step)
# INFO:tensorflow:global step 82: loss: 1.5459 (0.69 sec/step)
# INFO:tensorflow:global step 83: loss: 1.3490 (0.69 sec/step)
# INFO:tensorflow:global step 84: loss: 0.9192 (0.67 sec/step)
# INFO:tensorflow:global step 85: loss: 0.8703 (0.68 sec/step)
# INFO:tensorflow:global step 86: loss: 1.7599 (0.68 sec/step)
# INFO:tensorflow:global step 87: loss: 1.5936 (0.69 sec/step)
# INFO:tensorflow:global step 88: loss: 1.1026 (0.68 sec/step)
# INFO:tensorflow:global step 89: loss: 0.9708 (0.69 sec/step)
# INFO:tensorflow:global step 90: loss: 0.8522 (0.68 sec/step)
# INFO:tensorflow:global step 91: loss: 1.3371 (0.69 sec/step)
# INFO:tensorflow:global step 92: loss: 1.0306 (0.70 sec/step)
# INFO:tensorflow:global step 93: loss: 0.7940 (0.70 sec/step)
# INFO:tensorflow:global step 94: loss: 0.6438 (0.69 sec/step)
# INFO:tensorflow:global step 95: loss: 2.3344 (0.68 sec/step)
# INFO:tensorflow:global step 96: loss: 0.8504 (0.68 sec/step)
# INFO:tensorflow:global step 97: loss: 0.8507 (0.68 sec/step)
# INFO:tensorflow:global step 98: loss: 1.8583 (0.70 sec/step)
# INFO:tensorflow:global step 99: loss: 1.0795 (0.69 sec/step)
# INFO:tensorflow:global step 100: loss: 0.7839 (0.69 sec/step)
# INFO:tensorflow:global step 101: loss: 0.8015 (0.70 sec/step)
# INFO:tensorflow:global step 102: loss: 0.9022 (0.69 sec/step)
# INFO:tensorflow:global step 103: loss: 1.5622 (0.69 sec/step)
# INFO:tensorflow:global step 104: loss: 1.1926 (0.70 sec/step)
# INFO:tensorflow:global step 105: loss: 0.7689 (0.69 sec/step)
# INFO:tensorflow:global step 106: loss: 1.2524 (0.69 sec/step)
# INFO:tensorflow:global step 107: loss: 0.7421 (0.70 sec/step)
# INFO:tensorflow:global step 108: loss: 0.9632 (0.69 sec/step)
# INFO:tensorflow:global step 109: loss: 1.0458 (0.69 sec/step)
# INFO:tensorflow:global step 110: loss: 0.8315 (0.69 sec/step)
# INFO:tensorflow:global step 111: loss: 1.9611 (0.69 sec/step)
# INFO:tensorflow:global step 112: loss: 1.7796 (0.67 sec/step)
# INFO:tensorflow:global step 113: loss: 0.8565 (0.69 sec/step)
# INFO:tensorflow:global step 114: loss: 1.3536 (0.70 sec/step)
# INFO:tensorflow:global step 115: loss: 0.8533 (0.69 sec/step)
# INFO:tensorflow:global step 116: loss: 0.9128 (0.67 sec/step)
# INFO:tensorflow:global step 117: loss: 1.2177 (0.69 sec/step)
# INFO:tensorflow:global step 118: loss: 1.2676 (0.69 sec/step)
# INFO:tensorflow:global step 119: loss: 0.7750 (0.69 sec/step)
# INFO:tensorflow:global step 120: loss: 1.2622 (0.69 sec/step)
# INFO:tensorflow:global step 121: loss: 1.0634 (0.68 sec/step)
# INFO:tensorflow:global step 122: loss: 0.9280 (0.69 sec/step)
# INFO:tensorflow:global step 123: loss: 0.8335 (0.69 sec/step)
# INFO:tensorflow:global step 124: loss: 0.9909 (0.70 sec/step)
# INFO:tensorflow:global step 125: loss: 1.1301 (0.70 sec/step)
# INFO:tensorflow:global step 126: loss: 1.1030 (0.68 sec/step)
# INFO:tensorflow:global step 127: loss: 0.9758 (0.69 sec/step)
# INFO:tensorflow:global step 128: loss: 1.2508 (0.72 sec/step)
# INFO:tensorflow:global step 129: loss: 0.6836 (0.68 sec/step)
# INFO:tensorflow:global step 130: loss: 0.9548 (0.69 sec/step)
# INFO:tensorflow:global step 131: loss: 0.5701 (0.68 sec/step)
# INFO:tensorflow:global step 132: loss: 1.1243 (0.70 sec/step)
# INFO:tensorflow:global step 133: loss: 1.3273 (0.72 sec/step)
# INFO:tensorflow:global step 134: loss: 0.7137 (0.68 sec/step)
# INFO:tensorflow:global step 135: loss: 1.0937 (0.70 sec/step)
# INFO:tensorflow:global step 136: loss: 1.6859 (0.70 sec/step)
# INFO:tensorflow:global step 137: loss: 0.8898 (0.69 sec/step)
# INFO:tensorflow:global step 138: loss: 1.0761 (0.67 sec/step)
# INFO:tensorflow:global step 139: loss: 0.6814 (0.70 sec/step)
# INFO:tensorflow:global step 140: loss: 1.2426 (0.69 sec/step)
# INFO:tensorflow:global step 141: loss: 0.6732 (0.69 sec/step)
# INFO:tensorflow:global step 142: loss: 1.5706 (0.69 sec/step)
# INFO:tensorflow:global step 143: loss: 1.8476 (0.69 sec/step)
# INFO:tensorflow:global step 144: loss: 0.9326 (0.69 sec/step)
# INFO:tensorflow:global step 145: loss: 1.1074 (0.68 sec/step)
# INFO:tensorflow:global step 146: loss: 0.8920 (0.70 sec/step)
# INFO:tensorflow:global_step/sec: 1.22497
# INFO:tensorflow:global step 147: loss: 0.8667 (0.69 sec/step)
# INFO:tensorflow:global step 148: loss: 1.0847 (0.69 sec/step)
# INFO:tensorflow:global step 149: loss: 0.8394 (0.69 sec/step)
# INFO:tensorflow:global step 150: loss: 1.1297 (0.69 sec/step)
# INFO:tensorflow:global step 151: loss: 0.9904 (0.68 sec/step)
# INFO:tensorflow:global step 152: loss: 1.2757 (0.69 sec/step)
# INFO:tensorflow:global step 153: loss: 0.8429 (0.70 sec/step)
# INFO:tensorflow:global step 154: loss: 1.2119 (0.68 sec/step)
# INFO:tensorflow:global step 155: loss: 0.8579 (0.69 sec/step)
# INFO:tensorflow:global step 156: loss: 1.0187 (0.69 sec/step)
# INFO:tensorflow:global step 157: loss: 0.9185 (0.70 sec/step)
# INFO:tensorflow:global step 158: loss: 1.0113 (0.69 sec/step)
# INFO:tensorflow:global step 159: loss: 1.5843 (0.69 sec/step)
# INFO:tensorflow:global step 160: loss: 1.3283 (0.69 sec/step)
# INFO:tensorflow:global step 161: loss: 1.0086 (0.68 sec/step)
# INFO:tensorflow:global step 162: loss: 0.9002 (0.69 sec/step)
# INFO:tensorflow:global step 163: loss: 1.6636 (0.69 sec/step)
# INFO:tensorflow:global step 164: loss: 0.8968 (0.69 sec/step)
# INFO:tensorflow:global step 165: loss: 1.8939 (0.69 sec/step)
# INFO:tensorflow:global step 166: loss: 0.9598 (0.69 sec/step)
# INFO:tensorflow:global step 167: loss: 1.1086 (0.70 sec/step)
# INFO:tensorflow:global step 168: loss: 0.7747 (0.69 sec/step)
# INFO:tensorflow:global step 169: loss: 0.6061 (0.68 sec/step)
# INFO:tensorflow:global step 170: loss: 1.0356 (0.70 sec/step)
# INFO:tensorflow:global step 171: loss: 0.8582 (0.69 sec/step)
# INFO:tensorflow:global step 172: loss: 1.4277 (0.70 sec/step)
# INFO:tensorflow:global step 173: loss: 1.0637 (0.69 sec/step)
# INFO:tensorflow:global step 174: loss: 1.3101 (0.70 sec/step)
# INFO:tensorflow:global step 175: loss: 1.4436 (0.70 sec/step)
# INFO:tensorflow:global step 176: loss: 0.9044 (0.70 sec/step)
# INFO:tensorflow:global step 177: loss: 0.8588 (0.69 sec/step)
# INFO:tensorflow:global step 178: loss: 1.2012 (0.71 sec/step)
# INFO:tensorflow:global step 179: loss: 1.1826 (0.71 sec/step)
# INFO:tensorflow:global step 180: loss: 0.9607 (0.70 sec/step)
# INFO:tensorflow:global step 181: loss: 0.9588 (0.72 sec/step)
# INFO:tensorflow:global step 182: loss: 1.1401 (0.71 sec/step)
# INFO:tensorflow:global step 183: loss: 1.0742 (0.70 sec/step)
# INFO:tensorflow:global step 184: loss: 0.9368 (0.71 sec/step)
# INFO:tensorflow:global step 185: loss: 0.8606 (0.70 sec/step)
# INFO:tensorflow:global step 186: loss: 0.8064 (0.72 sec/step)
# INFO:tensorflow:global step 187: loss: 0.7817 (0.67 sec/step)
# INFO:tensorflow:global step 188: loss: 0.6316 (0.73 sec/step)
# INFO:tensorflow:global step 189: loss: 0.7053 (0.70 sec/step)
# INFO:tensorflow:global step 190: loss: 1.0011 (0.68 sec/step)
# INFO:tensorflow:global step 191: loss: 2.2438 (0.70 sec/step)
# INFO:tensorflow:global step 192: loss: 1.5767 (0.71 sec/step)
# INFO:tensorflow:global step 193: loss: 1.5801 (0.69 sec/step)
# INFO:tensorflow:global step 194: loss: 1.2729 (0.70 sec/step)
# INFO:tensorflow:global step 195: loss: 0.9261 (0.68 sec/step)
# INFO:tensorflow:global step 196: loss: 1.3932 (0.71 sec/step)
# INFO:tensorflow:global step 197: loss: 1.0796 (0.70 sec/step)
# INFO:tensorflow:global step 198: loss: 0.6771 (0.71 sec/step)
# INFO:tensorflow:global step 199: loss: 0.8368 (0.69 sec/step)
# INFO:tensorflow:global step 200: loss: 0.6677 (0.72 sec/step)
# INFO:tensorflow:global step 201: loss: 0.6267 (0.70 sec/step)
# INFO:tensorflow:global step 202: loss: 0.9090 (0.70 sec/step)
# INFO:tensorflow:global step 203: loss: 1.0087 (0.69 sec/step)
# INFO:tensorflow:global step 204: loss: 1.1559 (0.70 sec/step)
# INFO:tensorflow:global step 205: loss: 1.6159 (0.69 sec/step)
# INFO:tensorflow:global step 206: loss: 1.0201 (0.69 sec/step)
# INFO:tensorflow:global step 207: loss: 1.2476 (0.69 sec/step)
# INFO:tensorflow:global step 208: loss: 1.0470 (0.68 sec/step)
# INFO:tensorflow:global step 209: loss: 1.0076 (0.68 sec/step)
# INFO:tensorflow:global step 210: loss: 1.0854 (0.68 sec/step)
# INFO:tensorflow:global step 211: loss: 1.7846 (0.68 sec/step)
# INFO:tensorflow:global step 212: loss: 1.5008 (0.69 sec/step)
# INFO:tensorflow:global step 213: loss: 1.2400 (0.68 sec/step)
# INFO:tensorflow:global step 214: loss: 0.9839 (0.69 sec/step)
# INFO:tensorflow:global step 215: loss: 0.8066 (0.69 sec/step)
# INFO:tensorflow:global step 216: loss: 1.1081 (0.69 sec/step)
# INFO:tensorflow:global step 217: loss: 0.6808 (0.68 sec/step)
# INFO:tensorflow:global step 218: loss: 1.6240 (0.69 sec/step)
# INFO:tensorflow:global step 219: loss: 0.7260 (0.69 sec/step)
# INFO:tensorflow:global step 220: loss: 1.2716 (0.69 sec/step)
# INFO:tensorflow:global step 221: loss: 0.8641 (0.69 sec/step)
# INFO:tensorflow:global step 222: loss: 0.5911 (0.69 sec/step)
# INFO:tensorflow:global step 223: loss: 1.2665 (0.69 sec/step)
# INFO:tensorflow:global step 224: loss: 1.3137 (0.68 sec/step)
# INFO:tensorflow:global step 225: loss: 1.3775 (0.69 sec/step)
# INFO:tensorflow:global step 226: loss: 0.8047 (0.69 sec/step)
# INFO:tensorflow:global step 227: loss: 1.2614 (0.69 sec/step)
# INFO:tensorflow:global step 228: loss: 0.9915 (0.70 sec/step)
# INFO:tensorflow:global step 229: loss: 0.7532 (0.69 sec/step)
# INFO:tensorflow:global step 230: loss: 0.8355 (0.68 sec/step)
# INFO:tensorflow:global step 231: loss: 0.8303 (0.68 sec/step)
# INFO:tensorflow:global step 232: loss: 0.7928 (0.69 sec/step)
# INFO:tensorflow:global step 233: loss: 1.3666 (0.68 sec/step)
# INFO:tensorflow:global step 234: loss: 1.1764 (0.68 sec/step)
# INFO:tensorflow:global step 235: loss: 1.2328 (0.69 sec/step)
# INFO:tensorflow:global step 236: loss: 1.1656 (0.70 sec/step)
# INFO:tensorflow:global step 237: loss: 0.5542 (0.70 sec/step)
# INFO:tensorflow:global step 238: loss: 1.2301 (0.69 sec/step)
# INFO:tensorflow:global step 239: loss: 0.5710 (0.69 sec/step)
# INFO:tensorflow:global step 240: loss: 1.5475 (0.68 sec/step)
# INFO:tensorflow:global step 241: loss: 0.6157 (0.68 sec/step)
# INFO:tensorflow:global step 242: loss: 0.8027 (0.69 sec/step)
# INFO:tensorflow:global step 243: loss: 1.4789 (0.69 sec/step)
# INFO:tensorflow:global step 244: loss: 1.3715 (0.69 sec/step)
# INFO:tensorflow:global step 245: loss: 0.9932 (0.70 sec/step)
# INFO:tensorflow:global step 246: loss: 1.0186 (0.68 sec/step)
# INFO:tensorflow:global step 247: loss: 0.5974 (0.68 sec/step)
# INFO:tensorflow:global step 248: loss: 1.2525 (0.69 sec/step)
# INFO:tensorflow:global step 249: loss: 0.6590 (0.69 sec/step)
# INFO:tensorflow:global step 250: loss: 0.7252 (0.68 sec/step)
# INFO:tensorflow:global step 251: loss: 0.7656 (0.67 sec/step)
# INFO:tensorflow:global step 252: loss: 0.8506 (0.68 sec/step)
# INFO:tensorflow:global step 253: loss: 1.1245 (0.69 sec/step)
# INFO:tensorflow:global step 254: loss: 0.7129 (0.69 sec/step)
# INFO:tensorflow:global step 255: loss: 0.6106 (0.68 sec/step)
# INFO:tensorflow:Epoch 2.0/70
# INFO:tensorflow:Current Learning Rate: 0.0002
# INFO:tensorflow:Current Streaming Accuracy: 0.7757813
# logits:
#  [[-1.6785462  -0.7399469   5.2661433  -0.8832959  -0.9388031 ]
#  [-2.5299497   1.953581   -1.9659958   0.20143677  2.0115106 ]
#  [-0.42795452  3.6925452  -1.059499   -1.3031373  -0.06388567]
#  [-2.4063869  -3.6837013   0.6097155   9.509683   -1.8581257 ]
#  [-1.8170577  -1.7754061   4.508405   -2.3271585   1.9452512 ]
#  [-3.2942262  -0.14804697  0.48963448  2.0846148   0.81962264]
#  [ 9.60563     1.227169   -5.7112136  -0.7930532  -3.740066  ]
#  [-1.0332078  -3.9803832  -3.2615988   2.1331766   7.0294294 ]
#  [ 2.708164   -0.17641236 -1.446847   -1.0634975   0.1640912 ]
#  [-2.6511726   5.485201   -1.5508778  -3.1621065   1.7053672 ]]
# Probabilities:
#  [[9.5648773e-04 2.4451641e-03 9.9247557e-01 2.1186159e-03 2.0042218e-03]
#  [4.9878750e-03 4.4166002e-01 8.7667275e-03 7.6584607e-02 4.6800080e-01]
#  [1.5389886e-02 9.4786316e-01 8.1838761e-03 6.4142845e-03 2.2148710e-02]
#  [6.6811158e-06 1.8625934e-06 1.3637205e-04 9.9984348e-01 1.1559940e-05]
#  [1.6547882e-03 1.7251676e-03 9.2439163e-01 9.9359278e-04 7.1234830e-02]
#  [2.8886269e-03 6.7152120e-02 1.2705779e-01 6.2617022e-01 1.7673123e-01]
#  [9.9973804e-01 2.2970312e-04 2.2277466e-07 3.0464589e-05 1.5992792e-06]
#  [3.1264353e-04 1.6409962e-05 3.3672211e-05 7.4163950e-03 9.9222082e-01]
#  [8.5242510e-01 4.7632203e-02 1.3370813e-02 1.9617535e-02 6.6954441e-02]
#  [2.8578803e-04 9.7639638e-01 8.5880811e-04 1.7145426e-04 2.2287698e-02]]
# predictions:
#  [2 4 1 3 2 3 0 4 0 1]
# Labels:
# : [2 3 1 3 2 3 0 3 0 1]
# INFO:tensorflow:global step 256: loss: 1.0848 (0.69 sec/step)
# INFO:tensorflow:global step 257: loss: 1.1324 (0.69 sec/step)
# INFO:tensorflow:global step 258: loss: 0.7026 (0.68 sec/step)
# INFO:tensorflow:global step 259: loss: 1.0831 (0.69 sec/step)
# INFO:tensorflow:global step 260: loss: 0.8938 (0.69 sec/step)
# INFO:tensorflow:global step 261: loss: 1.1227 (0.68 sec/step)
# INFO:tensorflow:global step 262: loss: 1.0317 (0.67 sec/step)
# INFO:tensorflow:global step 263: loss: 0.6762 (0.70 sec/step)
# INFO:tensorflow:global step 264: loss: 1.1945 (0.69 sec/step)
# INFO:tensorflow:global step 265: loss: 1.3306 (0.69 sec/step)
# INFO:tensorflow:global step 266: loss: 0.8678 (0.68 sec/step)
# INFO:tensorflow:global step 267: loss: 1.0234 (0.69 sec/step)
# INFO:tensorflow:global step 268: loss: 1.1099 (0.68 sec/step)
# INFO:tensorflow:global step 269: loss: 0.7091 (0.70 sec/step)
# INFO:tensorflow:global step 270: loss: 1.0431 (0.69 sec/step)
# INFO:tensorflow:global step 271: loss: 0.7074 (0.69 sec/step)
# INFO:tensorflow:global step 272: loss: 0.9227 (0.69 sec/step)
# INFO:tensorflow:global step 273: loss: 1.6119 (0.68 sec/step)
# INFO:tensorflow:global step 274: loss: 0.8353 (0.68 sec/step)
# INFO:tensorflow:global step 275: loss: 0.9135 (0.68 sec/step)
# INFO:tensorflow:global step 276: loss: 1.1453 (0.69 sec/step)
# INFO:tensorflow:global step 277: loss: 0.6956 (0.69 sec/step)
# INFO:tensorflow:global step 278: loss: 0.7000 (0.69 sec/step)
# INFO:tensorflow:global step 279: loss: 1.3567 (0.67 sec/step)
# INFO:tensorflow:global step 280: loss: 0.6518 (0.68 sec/step)
# INFO:tensorflow:global step 281: loss: 0.7167 (0.68 sec/step)
# INFO:tensorflow:global step 282: loss: 0.7757 (0.69 sec/step)
# INFO:tensorflow:global step 283: loss: 0.6389 (0.68 sec/step)
# INFO:tensorflow:global step 284: loss: 0.7867 (0.70 sec/step)
# INFO:tensorflow:global step 285: loss: 0.5853 (0.68 sec/step)
# INFO:tensorflow:global step 286: loss: 1.1433 (0.69 sec/step)
# INFO:tensorflow:global step 287: loss: 0.8905 (0.69 sec/step)
# INFO:tensorflow:global step 288: loss: 1.4589 (0.69 sec/step)
# INFO:tensorflow:global step 289: loss: 0.7566 (0.70 sec/step)
# INFO:tensorflow:global step 290: loss: 0.9455 (0.68 sec/step)
# INFO:tensorflow:global step 291: loss: 0.9402 (0.70 sec/step)
# INFO:tensorflow:global step 292: loss: 0.7915 (0.68 sec/step)
# INFO:tensorflow:global step 293: loss: 1.3933 (0.70 sec/step)
# INFO:tensorflow:global step 294: loss: 1.1214 (0.69 sec/step)
# INFO:tensorflow:global step 295: loss: 0.7087 (0.70 sec/step)
# INFO:tensorflow:global step 296: loss: 1.0210 (0.69 sec/step)
# INFO:tensorflow:global step 297: loss: 1.1636 (0.70 sec/step)
# INFO:tensorflow:global step 298: loss: 1.5814 (0.69 sec/step)
# INFO:tensorflow:global step 299: loss: 1.0906 (0.70 sec/step)
# INFO:tensorflow:global step 300: loss: 0.7362 (0.70 sec/step)
# INFO:tensorflow:global step 301: loss: 1.1013 (0.69 sec/step)
# INFO:tensorflow:global step 302: loss: 0.9519 (0.68 sec/step)
# INFO:tensorflow:global step 303: loss: 1.2024 (0.68 sec/step)
# INFO:tensorflow:global step 304: loss: 0.6167 (0.69 sec/step)
# INFO:tensorflow:global step 305: loss: 0.9190 (0.69 sec/step)
# INFO:tensorflow:global step 306: loss: 1.4978 (0.70 sec/step)
# INFO:tensorflow:global step 307: loss: 0.9792 (0.68 sec/step)
# INFO:tensorflow:global step 308: loss: 0.8887 (0.70 sec/step)
# INFO:tensorflow:global step 309: loss: 0.7612 (0.70 sec/step)
# INFO:tensorflow:global step 310: loss: 1.0750 (0.67 sec/step)
# INFO:tensorflow:global step 311: loss: 0.9519 (0.69 sec/step)
# INFO:tensorflow:global step 312: loss: 0.9207 (0.69 sec/step)
# INFO:tensorflow:global step 313: loss: 1.1173 (0.69 sec/step)
# INFO:tensorflow:global step 314: loss: 0.8525 (0.69 sec/step)
# INFO:tensorflow:global_step/sec: 1.39947
# INFO:tensorflow:global step 315: loss: 0.9034 (0.68 sec/step)
# INFO:tensorflow:global step 316: loss: 0.5985 (0.70 sec/step)
# INFO:tensorflow:global step 317: loss: 0.7773 (0.69 sec/step)
# INFO:tensorflow:global step 318: loss: 0.6151 (0.69 sec/step)
# INFO:tensorflow:global step 319: loss: 0.8478 (0.70 sec/step)
# INFO:tensorflow:global step 320: loss: 1.0070 (0.69 sec/step)
# INFO:tensorflow:global step 321: loss: 1.1480 (0.69 sec/step)
# INFO:tensorflow:global step 322: loss: 1.0264 (0.68 sec/step)
# INFO:tensorflow:global step 323: loss: 1.2785 (0.68 sec/step)
# INFO:tensorflow:global step 324: loss: 0.7217 (0.68 sec/step)
# INFO:tensorflow:global step 325: loss: 0.9311 (0.70 sec/step)
# INFO:tensorflow:global step 326: loss: 0.7583 (0.69 sec/step)
# INFO:tensorflow:global step 327: loss: 1.2982 (0.69 sec/step)
# INFO:tensorflow:global step 328: loss: 1.0752 (0.69 sec/step)
# INFO:tensorflow:global step 329: loss: 1.1742 (0.69 sec/step)
# INFO:tensorflow:global step 330: loss: 0.8074 (0.68 sec/step)
# INFO:tensorflow:global step 331: loss: 0.6566 (0.67 sec/step)
# INFO:tensorflow:global step 332: loss: 0.8170 (0.70 sec/step)
# INFO:tensorflow:global step 333: loss: 0.8252 (0.68 sec/step)
# INFO:tensorflow:global step 334: loss: 0.7867 (0.69 sec/step)
# INFO:tensorflow:global step 335: loss: 0.7580 (0.70 sec/step)
# INFO:tensorflow:global step 336: loss: 0.7994 (0.70 sec/step)
# INFO:tensorflow:global step 337: loss: 1.1055 (0.70 sec/step)
# INFO:tensorflow:global step 338: loss: 0.9128 (0.69 sec/step)
# INFO:tensorflow:global step 339: loss: 0.7133 (0.69 sec/step)
# INFO:tensorflow:global step 340: loss: 0.7452 (0.69 sec/step)
# INFO:tensorflow:global step 341: loss: 0.7300 (0.68 sec/step)
# INFO:tensorflow:global step 342: loss: 1.2461 (0.69 sec/step)
# INFO:tensorflow:global step 343: loss: 0.8596 (0.69 sec/step)
# INFO:tensorflow:global step 344: loss: 1.1060 (0.69 sec/step)
# INFO:tensorflow:global step 345: loss: 0.9171 (0.68 sec/step)
# INFO:tensorflow:global step 346: loss: 1.4980 (0.69 sec/step)
# INFO:tensorflow:global step 347: loss: 0.7745 (0.68 sec/step)
# INFO:tensorflow:global step 348: loss: 0.7912 (0.69 sec/step)
# INFO:tensorflow:global step 349: loss: 0.7943 (0.68 sec/step)
# INFO:tensorflow:global step 350: loss: 0.7051 (0.69 sec/step)
# INFO:tensorflow:global step 351: loss: 1.0884 (0.68 sec/step)
# INFO:tensorflow:global step 352: loss: 0.7834 (0.67 sec/step)
# INFO:tensorflow:global step 353: loss: 0.9290 (0.70 sec/step)
# INFO:tensorflow:global step 354: loss: 1.0479 (0.67 sec/step)
# INFO:tensorflow:global step 355: loss: 0.8151 (0.69 sec/step)
# INFO:tensorflow:global step 356: loss: 1.0630 (0.69 sec/step)
# INFO:tensorflow:global step 357: loss: 1.2091 (0.68 sec/step)
# INFO:tensorflow:global step 358: loss: 0.7403 (0.69 sec/step)
# INFO:tensorflow:global step 359: loss: 0.9947 (0.68 sec/step)
# INFO:tensorflow:global step 360: loss: 0.5845 (0.69 sec/step)
# INFO:tensorflow:global step 361: loss: 1.3554 (0.67 sec/step)
# INFO:tensorflow:global step 362: loss: 0.7424 (0.69 sec/step)
# INFO:tensorflow:global step 363: loss: 0.9903 (0.69 sec/step)
# INFO:tensorflow:global step 364: loss: 1.1011 (0.68 sec/step)
# INFO:tensorflow:global step 365: loss: 0.8529 (0.69 sec/step)
# INFO:tensorflow:global step 366: loss: 0.7394 (0.68 sec/step)
# INFO:tensorflow:global step 367: loss: 1.3175 (0.69 sec/step)
# INFO:tensorflow:global step 368: loss: 1.2188 (0.70 sec/step)
# INFO:tensorflow:global step 369: loss: 0.6502 (0.69 sec/step)
# INFO:tensorflow:global step 370: loss: 1.0083 (0.68 sec/step)
# INFO:tensorflow:global step 371: loss: 0.8377 (0.70 sec/step)
# INFO:tensorflow:global step 372: loss: 0.9579 (0.69 sec/step)
# INFO:tensorflow:global step 373: loss: 0.8892 (0.69 sec/step)
# INFO:tensorflow:global step 374: loss: 1.2067 (0.68 sec/step)
# INFO:tensorflow:global step 375: loss: 0.6647 (0.69 sec/step)
# INFO:tensorflow:global step 376: loss: 1.1706 (0.70 sec/step)
# INFO:tensorflow:global step 377: loss: 0.7238 (0.70 sec/step)
# INFO:tensorflow:global step 378: loss: 0.9337 (0.69 sec/step)
# INFO:tensorflow:global step 379: loss: 0.7886 (0.69 sec/step)
# INFO:tensorflow:global step 380: loss: 1.2185 (0.71 sec/step)
# INFO:tensorflow:global step 381: loss: 0.7499 (0.69 sec/step)
# INFO:tensorflow:global step 382: loss: 0.8675 (0.68 sec/step)
# INFO:tensorflow:global step 383: loss: 0.8776 (0.68 sec/step)
# INFO:tensorflow:global step 384: loss: 0.8015 (0.69 sec/step)
# INFO:tensorflow:global step 385: loss: 1.7591 (0.69 sec/step)
# INFO:tensorflow:global step 386: loss: 1.0490 (0.69 sec/step)
# INFO:tensorflow:global step 387: loss: 1.0094 (0.69 sec/step)
# INFO:tensorflow:global step 388: loss: 0.9121 (0.69 sec/step)
# INFO:tensorflow:global step 389: loss: 1.4020 (0.68 sec/step)
# INFO:tensorflow:global step 390: loss: 0.7948 (0.69 sec/step)
# INFO:tensorflow:global step 391: loss: 0.8350 (0.68 sec/step)
# INFO:tensorflow:global step 392: loss: 1.2913 (0.69 sec/step)
# INFO:tensorflow:global step 393: loss: 0.9370 (0.69 sec/step)
# INFO:tensorflow:global step 394: loss: 0.8292 (0.69 sec/step)
# INFO:tensorflow:global step 395: loss: 0.8206 (0.69 sec/step)
# INFO:tensorflow:global step 396: loss: 0.8976 (0.69 sec/step)
# INFO:tensorflow:global step 397: loss: 0.8727 (0.70 sec/step)
# INFO:tensorflow:global step 398: loss: 1.3716 (0.69 sec/step)
# INFO:tensorflow:global step 399: loss: 0.6509 (0.70 sec/step)
# INFO:tensorflow:global step 400: loss: 0.8898 (0.69 sec/step)
# INFO:tensorflow:global step 401: loss: 0.7794 (0.69 sec/step)
# INFO:tensorflow:global step 402: loss: 0.7245 (0.69 sec/step)
# INFO:tensorflow:global step 403: loss: 0.8159 (0.69 sec/step)
# INFO:tensorflow:global step 404: loss: 1.1074 (0.69 sec/step)
# INFO:tensorflow:global step 405: loss: 1.5508 (0.68 sec/step)
# INFO:tensorflow:global step 406: loss: 0.9194 (0.69 sec/step)
# INFO:tensorflow:global step 407: loss: 0.6656 (0.70 sec/step)
# INFO:tensorflow:global step 408: loss: 0.8476 (0.68 sec/step)
# INFO:tensorflow:global step 409: loss: 0.9933 (0.68 sec/step)
# INFO:tensorflow:global step 410: loss: 0.7184 (0.67 sec/step)
# INFO:tensorflow:global step 411: loss: 0.6671 (0.69 sec/step)
# INFO:tensorflow:global step 412: loss: 1.3039 (0.69 sec/step)
# INFO:tensorflow:global step 413: loss: 0.8537 (0.69 sec/step)
# INFO:tensorflow:global step 414: loss: 0.9770 (0.68 sec/step)
# INFO:tensorflow:global step 415: loss: 0.8138 (0.68 sec/step)
# INFO:tensorflow:global step 416: loss: 0.9391 (0.69 sec/step)
# INFO:tensorflow:global step 417: loss: 0.8630 (0.69 sec/step)
# INFO:tensorflow:global step 418: loss: 1.6389 (0.69 sec/step)
# INFO:tensorflow:global step 419: loss: 0.8850 (0.70 sec/step)
# INFO:tensorflow:global step 420: loss: 0.8104 (0.69 sec/step)
# INFO:tensorflow:global step 421: loss: 1.3083 (0.71 sec/step)
# INFO:tensorflow:global step 422: loss: 0.7317 (0.69 sec/step)
# INFO:tensorflow:global step 423: loss: 1.0497 (0.67 sec/step)
# INFO:tensorflow:global step 424: loss: 0.6057 (0.69 sec/step)
# INFO:tensorflow:global step 425: loss: 0.6361 (0.70 sec/step)
# INFO:tensorflow:global step 426: loss: 1.0042 (0.69 sec/step)
# INFO:tensorflow:global step 427: loss: 0.7111 (0.68 sec/step)
# INFO:tensorflow:global step 428: loss: 1.2921 (0.69 sec/step)
# INFO:tensorflow:global step 429: loss: 1.2152 (0.69 sec/step)
# INFO:tensorflow:global step 430: loss: 0.8336 (0.69 sec/step)
# INFO:tensorflow:global step 431: loss: 1.7941 (0.68 sec/step)
# INFO:tensorflow:global step 432: loss: 0.6977 (0.70 sec/step)
# INFO:tensorflow:global step 433: loss: 0.7468 (0.69 sec/step)
# INFO:tensorflow:global step 434: loss: 0.9087 (0.69 sec/step)
# INFO:tensorflow:global step 435: loss: 1.2748 (0.69 sec/step)
# INFO:tensorflow:global step 436: loss: 1.5547 (0.68 sec/step)
# INFO:tensorflow:global step 437: loss: 0.9718 (0.69 sec/step)
# INFO:tensorflow:global step 438: loss: 0.8958 (0.69 sec/step)
# INFO:tensorflow:global step 439: loss: 0.8047 (0.69 sec/step)
# INFO:tensorflow:global step 440: loss: 0.9985 (0.69 sec/step)
# INFO:tensorflow:global step 441: loss: 1.1568 (0.71 sec/step)
# INFO:tensorflow:global step 442: loss: 1.1865 (0.69 sec/step)
# INFO:tensorflow:global step 443: loss: 0.9265 (0.69 sec/step)
# INFO:tensorflow:global step 444: loss: 0.6289 (0.70 sec/step)
# INFO:tensorflow:global step 445: loss: 0.7952 (0.70 sec/step)
# INFO:tensorflow:global step 446: loss: 0.8396 (0.70 sec/step)
# INFO:tensorflow:global step 447: loss: 1.2866 (0.70 sec/step)
# INFO:tensorflow:global step 448: loss: 1.2584 (0.69 sec/step)
# INFO:tensorflow:global step 449: loss: 1.0088 (0.69 sec/step)
# INFO:tensorflow:global step 450: loss: 0.9878 (0.69 sec/step)
# INFO:tensorflow:global step 451: loss: 1.1140 (0.69 sec/step)
# INFO:tensorflow:global step 452: loss: 1.3419 (0.69 sec/step)
# INFO:tensorflow:global step 453: loss: 0.9444 (0.68 sec/step)
# INFO:tensorflow:global step 454: loss: 0.7708 (0.68 sec/step)
# INFO:tensorflow:global step 455: loss: 0.7610 (0.68 sec/step)
# INFO:tensorflow:global step 456: loss: 1.1425 (0.68 sec/step)
# INFO:tensorflow:global step 457: loss: 1.2828 (0.69 sec/step)
# INFO:tensorflow:global step 458: loss: 1.0355 (0.68 sec/step)
# INFO:tensorflow:global step 459: loss: 0.7566 (0.69 sec/step)
# INFO:tensorflow:global step 460: loss: 0.9464 (0.69 sec/step)
# INFO:tensorflow:global step 461: loss: 0.7868 (0.68 sec/step)
# INFO:tensorflow:global step 462: loss: 0.7682 (0.69 sec/step)
# INFO:tensorflow:global step 463: loss: 0.7917 (0.69 sec/step)
# INFO:tensorflow:global step 464: loss: 0.7296 (0.69 sec/step)
# INFO:tensorflow:global step 465: loss: 0.9547 (0.70 sec/step)
# INFO:tensorflow:global step 466: loss: 0.9722 (0.68 sec/step)
# INFO:tensorflow:global step 467: loss: 0.7330 (0.70 sec/step)
# INFO:tensorflow:global step 468: loss: 1.1346 (0.68 sec/step)
# INFO:tensorflow:global step 469: loss: 0.5764 (0.69 sec/step)
# INFO:tensorflow:global step 470: loss: 0.7185 (0.68 sec/step)
# INFO:tensorflow:global step 471: loss: 0.9660 (0.68 sec/step)
# INFO:tensorflow:global step 472: loss: 1.1426 (0.69 sec/step)
# INFO:tensorflow:global step 473: loss: 0.7589 (0.68 sec/step)
# INFO:tensorflow:global step 474: loss: 0.8124 (0.68 sec/step)
# INFO:tensorflow:global step 475: loss: 0.8803 (0.68 sec/step)
# INFO:tensorflow:global step 476: loss: 1.0052 (0.69 sec/step)
# INFO:tensorflow:global step 477: loss: 0.8496 (0.67 sec/step)
# INFO:tensorflow:global step 478: loss: 1.8754 (0.70 sec/step)
# INFO:tensorflow:global step 479: loss: 0.8444 (0.68 sec/step)
# INFO:tensorflow:global step 480: loss: 0.6650 (0.68 sec/step)
# INFO:tensorflow:global step 481: loss: 1.5284 (0.68 sec/step)
# INFO:tensorflow:global step 482: loss: 0.5621 (0.69 sec/step)
# INFO:tensorflow:global_step/sec: 1.40028
# INFO:tensorflow:global step 483: loss: 0.9990 (0.69 sec/step)
# INFO:tensorflow:global step 484: loss: 0.6199 (0.68 sec/step)
# INFO:tensorflow:global step 485: loss: 1.6563 (0.69 sec/step)
# INFO:tensorflow:global step 486: loss: 0.5636 (0.68 sec/step)
# INFO:tensorflow:global step 487: loss: 0.8581 (0.69 sec/step)
# INFO:tensorflow:global step 488: loss: 1.1269 (0.69 sec/step)
# INFO:tensorflow:global step 489: loss: 0.7276 (0.68 sec/step)
# INFO:tensorflow:global step 490: loss: 0.6466 (0.69 sec/step)
# INFO:tensorflow:global step 491: loss: 1.0500 (0.67 sec/step)
# INFO:tensorflow:global step 492: loss: 1.0785 (0.68 sec/step)
# INFO:tensorflow:global step 493: loss: 0.6317 (0.69 sec/step)
# INFO:tensorflow:global step 494: loss: 0.7107 (0.69 sec/step)
# INFO:tensorflow:global step 495: loss: 1.5996 (0.70 sec/step)
# INFO:tensorflow:global step 496: loss: 0.9935 (0.69 sec/step)
# INFO:tensorflow:global step 497: loss: 0.5954 (0.69 sec/step)
# INFO:tensorflow:global step 498: loss: 0.7562 (0.70 sec/step)
# INFO:tensorflow:global step 499: loss: 1.1901 (0.68 sec/step)
# INFO:tensorflow:global step 500: loss: 0.9236 (0.67 sec/step)
# INFO:tensorflow:global step 501: loss: 0.8800 (0.69 sec/step)
# INFO:tensorflow:global step 502: loss: 0.5593 (0.69 sec/step)
# INFO:tensorflow:global step 503: loss: 0.6901 (0.69 sec/step)
# INFO:tensorflow:global step 504: loss: 1.3047 (0.69 sec/step)
# INFO:tensorflow:global step 505: loss: 1.0689 (0.69 sec/step)
# INFO:tensorflow:global step 506: loss: 0.7223 (0.68 sec/step)
# INFO:tensorflow:global step 507: loss: 0.6261 (0.69 sec/step)
# INFO:tensorflow:global step 508: loss: 0.8551 (0.67 sec/step)
# INFO:tensorflow:global step 509: loss: 0.7956 (0.70 sec/step)
# INFO:tensorflow:global step 510: loss: 0.5320 (0.69 sec/step)
# INFO:tensorflow:global step 511: loss: 0.7491 (0.68 sec/step)
# INFO:tensorflow:Epoch 3.0/70
# INFO:tensorflow:Current Learning Rate: 0.00013999999
# INFO:tensorflow:Current Streaming Accuracy: 0.81210935
# logits:
#  [[-0.9127911   4.271508   -2.691673   -0.10293857 -0.19239171]
#  [-4.8135753  -0.49988645  2.2053316   2.5004363   0.97671795]
#  [ 4.9639516  -2.3173382  -2.3343132   1.4519784  -0.5309289 ]
#  [ 0.95043004 -0.0719692  -0.9245255  -0.37414518 -0.24413238]
#  [-0.66150033 -2.6343148   5.670194   -2.6032674   1.8953921 ]
#  [ 0.0874074  -3.2288182   7.95492    -3.37743     0.94798595]
#  [-2.0074894  -0.17806962 -2.5950801  -0.1343773   4.5680256 ]
#  [-0.27235875  1.3963196  -0.78521067 -1.0551505   0.2913453 ]
#  [ 7.0682864  -2.536185   -1.0307789  -0.62015104 -2.044968  ]
#  [-2.0426934  10.720125   -8.277154    1.6397226  -0.9017671 ]]
# Probabilities:
#  [[5.43714501e-03 9.70249772e-01 9.17935686e-04 1.22203995e-02
#   1.11747133e-02]
#  [3.30953102e-04 2.47273557e-02 3.69861364e-01 4.96822596e-01
#   1.08257718e-01]
#  [9.65893567e-01 6.64821651e-04 6.53631985e-04 2.88203135e-02
#   3.96764604e-03]
#  [4.80343133e-01 1.72794238e-01 7.36662820e-02 1.27730876e-01
#   1.45465404e-01]
#  [1.73524779e-03 2.41312067e-04 9.75397289e-01 2.48921802e-04
#   2.23772023e-02]
#  [3.82483238e-04 1.38801424e-05 9.98687327e-01 1.19633432e-05
#   9.04392393e-04]
#  [1.36684976e-03 8.51584226e-03 7.59509450e-04 8.89616553e-03
#   9.80461597e-01]
#  [1.09670356e-01 5.81817865e-01 6.56690150e-02 5.01333922e-02
#   1.92709371e-01]
#  [9.99061286e-01 6.73632894e-05 3.03537643e-04 4.57663380e-04
#   1.10092056e-04]
#  [2.86499494e-06 9.99874353e-01 5.61735014e-09 1.13861475e-04
#   8.96647725e-06]]
# predictions:
#  [1 3 0 0 2 2 4 1 0 1]
# Labels:
# : [1 2 0 0 2 2 4 2 0 1]
# INFO:tensorflow:global step 512: loss: 0.6687 (0.69 sec/step)
# INFO:tensorflow:global step 513: loss: 0.7332 (0.69 sec/step)
# INFO:tensorflow:global step 514: loss: 0.9624 (0.69 sec/step)
# INFO:tensorflow:global step 515: loss: 1.2917 (0.69 sec/step)
# INFO:tensorflow:global step 516: loss: 1.0069 (0.68 sec/step)
# INFO:tensorflow:global step 517: loss: 0.8416 (0.69 sec/step)
# INFO:tensorflow:global step 518: loss: 0.7380 (0.70 sec/step)
# INFO:tensorflow:global step 519: loss: 0.7118 (0.67 sec/step)
# INFO:tensorflow:global step 520: loss: 0.9750 (0.70 sec/step)
# INFO:tensorflow:global step 521: loss: 0.7950 (0.68 sec/step)
# INFO:tensorflow:global step 522: loss: 0.9287 (0.69 sec/step)
# INFO:tensorflow:global step 523: loss: 1.0647 (0.68 sec/step)
# INFO:tensorflow:global step 524: loss: 0.6556 (0.69 sec/step)
# INFO:tensorflow:global step 525: loss: 0.9198 (0.69 sec/step)
# INFO:tensorflow:global step 526: loss: 0.6268 (0.68 sec/step)
# INFO:tensorflow:global step 527: loss: 1.0994 (0.70 sec/step)
# INFO:tensorflow:global step 528: loss: 0.6017 (0.69 sec/step)
# INFO:tensorflow:global step 529: loss: 0.6257 (0.69 sec/step)
# INFO:tensorflow:global step 530: loss: 0.5995 (0.69 sec/step)
# INFO:tensorflow:global step 531: loss: 0.7288 (0.68 sec/step)
# INFO:tensorflow:global step 532: loss: 0.9100 (0.69 sec/step)
# INFO:tensorflow:global step 533: loss: 0.8660 (0.69 sec/step)
# INFO:tensorflow:global step 534: loss: 0.8888 (0.70 sec/step)
# INFO:tensorflow:global step 535: loss: 0.6768 (0.69 sec/step)
# INFO:tensorflow:global step 536: loss: 1.2291 (0.69 sec/step)
# INFO:tensorflow:global step 537: loss: 0.6243 (0.70 sec/step)
# INFO:tensorflow:global step 538: loss: 0.7085 (0.69 sec/step)
# INFO:tensorflow:global step 539: loss: 0.5821 (0.67 sec/step)
# INFO:tensorflow:global step 540: loss: 1.1232 (0.68 sec/step)
# INFO:tensorflow:global step 541: loss: 0.5876 (0.69 sec/step)
# INFO:tensorflow:global step 542: loss: 0.8945 (0.68 sec/step)
# INFO:tensorflow:global step 543: loss: 0.7001 (0.69 sec/step)
# INFO:tensorflow:global step 544: loss: 1.2916 (0.68 sec/step)
# INFO:tensorflow:global step 545: loss: 0.6015 (0.68 sec/step)
# INFO:tensorflow:global step 546: loss: 1.1347 (0.69 sec/step)
# INFO:tensorflow:global step 547: loss: 0.8162 (0.68 sec/step)
# INFO:tensorflow:global step 548: loss: 0.5912 (0.68 sec/step)
# INFO:tensorflow:global step 549: loss: 0.7686 (0.68 sec/step)
# INFO:tensorflow:global step 550: loss: 0.6755 (0.68 sec/step)
# INFO:tensorflow:global step 551: loss: 0.6258 (0.68 sec/step)
# INFO:tensorflow:global step 552: loss: 0.6323 (0.68 sec/step)
# INFO:tensorflow:global step 553: loss: 0.6203 (0.69 sec/step)
# INFO:tensorflow:global step 554: loss: 0.6157 (0.68 sec/step)
# INFO:tensorflow:global step 555: loss: 0.8538 (0.69 sec/step)
# INFO:tensorflow:global step 556: loss: 0.5630 (0.68 sec/step)
# INFO:tensorflow:global step 557: loss: 0.7754 (0.67 sec/step)
# INFO:tensorflow:global step 558: loss: 0.7408 (0.67 sec/step)
# INFO:tensorflow:global step 559: loss: 1.0422 (0.68 sec/step)
# INFO:tensorflow:global step 560: loss: 0.7817 (0.67 sec/step)
# INFO:tensorflow:global step 561: loss: 1.5662 (0.68 sec/step)
# INFO:tensorflow:global step 562: loss: 0.7847 (0.68 sec/step)
# INFO:tensorflow:global step 563: loss: 0.7417 (0.68 sec/step)
# INFO:tensorflow:global step 564: loss: 0.5783 (0.70 sec/step)
# INFO:tensorflow:global step 565: loss: 0.5966 (0.69 sec/step)
# INFO:tensorflow:global step 566: loss: 0.8282 (0.69 sec/step)
# INFO:tensorflow:global step 567: loss: 0.7760 (0.68 sec/step)
# INFO:tensorflow:global step 568: loss: 0.6720 (0.70 sec/step)
# INFO:tensorflow:global step 569: loss: 0.6375 (0.68 sec/step)
# INFO:tensorflow:global step 570: loss: 0.5875 (0.69 sec/step)
# INFO:tensorflow:global step 571: loss: 1.1131 (0.68 sec/step)
# INFO:tensorflow:global step 572: loss: 0.7196 (0.69 sec/step)
# INFO:tensorflow:global step 573: loss: 1.1486 (0.67 sec/step)
# INFO:tensorflow:global step 574: loss: 1.3027 (0.70 sec/step)
# INFO:tensorflow:global step 575: loss: 0.8914 (0.69 sec/step)
# INFO:tensorflow:global step 576: loss: 1.1060 (0.69 sec/step)
# INFO:tensorflow:global step 577: loss: 0.7706 (0.68 sec/step)
# INFO:tensorflow:global step 578: loss: 0.7728 (0.68 sec/step)
# INFO:tensorflow:global step 579: loss: 0.7345 (0.69 sec/step)
# INFO:tensorflow:global step 580: loss: 1.2302 (0.68 sec/step)
# INFO:tensorflow:global step 581: loss: 0.6916 (0.69 sec/step)
# INFO:tensorflow:global step 582: loss: 0.7203 (0.69 sec/step)
# INFO:tensorflow:global step 583: loss: 1.1854 (0.69 sec/step)
# INFO:tensorflow:global step 584: loss: 0.9415 (0.68 sec/step)
# INFO:tensorflow:global step 585: loss: 0.5392 (0.68 sec/step)
# INFO:tensorflow:global step 586: loss: 0.6097 (0.69 sec/step)
# INFO:tensorflow:global step 587: loss: 1.0222 (0.69 sec/step)
# INFO:tensorflow:global step 588: loss: 0.7608 (0.68 sec/step)
# INFO:tensorflow:global step 589: loss: 1.2161 (0.69 sec/step)
# INFO:tensorflow:global step 590: loss: 0.8036 (0.69 sec/step)
# INFO:tensorflow:global step 591: loss: 0.7397 (0.68 sec/step)
# INFO:tensorflow:global step 592: loss: 0.8755 (0.70 sec/step)
# INFO:tensorflow:global step 593: loss: 0.6485 (0.68 sec/step)
# INFO:tensorflow:global step 594: loss: 1.0350 (0.69 sec/step)
# INFO:tensorflow:global step 595: loss: 0.5675 (0.68 sec/step)
# INFO:tensorflow:global step 596: loss: 1.4439 (0.70 sec/step)
# INFO:tensorflow:global step 597: loss: 0.8807 (0.70 sec/step)
# INFO:tensorflow:global step 598: loss: 0.9316 (0.69 sec/step)
# INFO:tensorflow:global step 599: loss: 0.6600 (0.69 sec/step)
# INFO:tensorflow:global step 600: loss: 1.2976 (0.69 sec/step)
# INFO:tensorflow:global step 601: loss: 0.7531 (0.68 sec/step)
# INFO:tensorflow:global step 602: loss: 0.8021 (0.68 sec/step)
# INFO:tensorflow:global step 603: loss: 1.5861 (0.70 sec/step)
# INFO:tensorflow:global step 604: loss: 0.8254 (0.69 sec/step)
# INFO:tensorflow:global step 605: loss: 1.0481 (0.69 sec/step)
# INFO:tensorflow:global step 606: loss: 0.7354 (0.68 sec/step)
# INFO:tensorflow:global step 607: loss: 0.5831 (0.68 sec/step)
# INFO:tensorflow:global step 608: loss: 0.8671 (0.70 sec/step)
# INFO:tensorflow:global step 609: loss: 0.6536 (0.69 sec/step)
# INFO:tensorflow:global step 610: loss: 0.7817 (0.70 sec/step)
# INFO:tensorflow:global step 611: loss: 0.6764 (0.70 sec/step)
# INFO:tensorflow:global step 612: loss: 0.8507 (0.68 sec/step)
# INFO:tensorflow:global step 613: loss: 1.0515 (0.68 sec/step)
# INFO:tensorflow:global step 614: loss: 0.8643 (0.68 sec/step)
# INFO:tensorflow:global step 615: loss: 0.8281 (0.69 sec/step)
# INFO:tensorflow:global step 616: loss: 0.7522 (0.69 sec/step)
# INFO:tensorflow:global step 617: loss: 0.6764 (0.79 sec/step)
# INFO:tensorflow:global step 618: loss: 1.3910 (0.69 sec/step)
# INFO:tensorflow:global step 619: loss: 0.7163 (0.69 sec/step)
# INFO:tensorflow:global step 620: loss: 0.7149 (0.70 sec/step)
# INFO:tensorflow:global step 621: loss: 0.7407 (0.69 sec/step)
# INFO:tensorflow:global step 622: loss: 0.6191 (0.68 sec/step)
# INFO:tensorflow:global step 623: loss: 0.6870 (0.69 sec/step)
# INFO:tensorflow:global step 624: loss: 0.9835 (0.67 sec/step)
# INFO:tensorflow:global step 625: loss: 0.9569 (0.69 sec/step)
# INFO:tensorflow:global step 626: loss: 0.9110 (0.68 sec/step)
# INFO:tensorflow:global step 627: loss: 0.7782 (0.69 sec/step)
# INFO:tensorflow:global step 628: loss: 0.6658 (0.69 sec/step)
# INFO:tensorflow:global step 629: loss: 0.5991 (0.69 sec/step)
# INFO:tensorflow:global step 630: loss: 0.5912 (0.69 sec/step)
# INFO:tensorflow:global step 631: loss: 0.6867 (0.69 sec/step)
# INFO:tensorflow:global step 632: loss: 0.8614 (0.69 sec/step)
# INFO:tensorflow:global step 633: loss: 0.9426 (0.68 sec/step)
# INFO:tensorflow:global step 634: loss: 0.9966 (0.69 sec/step)
# INFO:tensorflow:global step 635: loss: 0.6778 (0.69 sec/step)
# INFO:tensorflow:global step 636: loss: 0.5338 (0.69 sec/step)
# INFO:tensorflow:global step 637: loss: 0.6743 (0.68 sec/step)
# INFO:tensorflow:global step 638: loss: 0.8470 (0.69 sec/step)
# INFO:tensorflow:global step 639: loss: 0.7488 (0.69 sec/step)
# INFO:tensorflow:global step 640: loss: 0.9986 (0.68 sec/step)
# INFO:tensorflow:global step 641: loss: 0.6890 (0.69 sec/step)
# INFO:tensorflow:global step 642: loss: 1.1944 (0.68 sec/step)
# INFO:tensorflow:global step 643: loss: 0.7839 (0.70 sec/step)
# INFO:tensorflow:global step 644: loss: 0.6306 (0.69 sec/step)
# INFO:tensorflow:global step 645: loss: 0.5950 (0.68 sec/step)
# INFO:tensorflow:global step 646: loss: 0.9021 (0.69 sec/step)
# INFO:tensorflow:global step 647: loss: 0.8176 (0.69 sec/step)
# INFO:tensorflow:global step 648: loss: 0.6404 (0.69 sec/step)
# INFO:tensorflow:global step 649: loss: 0.7916 (0.69 sec/step)
# INFO:tensorflow:global step 650: loss: 0.8488 (0.67 sec/step)
# INFO:tensorflow:global step 651: loss: 0.6107 (0.67 sec/step)
# INFO:tensorflow:global_step/sec: 1.40852
# INFO:tensorflow:global step 652: loss: 0.7081 (0.70 sec/step)
# INFO:tensorflow:global step 653: loss: 1.1184 (0.69 sec/step)
# INFO:tensorflow:global step 654: loss: 0.9795 (0.67 sec/step)
# INFO:tensorflow:global step 655: loss: 1.1215 (0.69 sec/step)
# INFO:tensorflow:global step 656: loss: 0.8758 (0.68 sec/step)
# INFO:tensorflow:global step 657: loss: 1.0239 (0.69 sec/step)
# INFO:tensorflow:global step 658: loss: 0.8056 (0.69 sec/step)
# INFO:tensorflow:global step 659: loss: 0.5282 (0.70 sec/step)
# INFO:tensorflow:global step 660: loss: 1.0098 (0.69 sec/step)
# INFO:tensorflow:global step 661: loss: 0.6541 (0.69 sec/step)
# INFO:tensorflow:global step 662: loss: 0.6324 (0.70 sec/step)
# INFO:tensorflow:global step 663: loss: 0.9333 (0.69 sec/step)
# INFO:tensorflow:global step 664: loss: 0.6444 (0.69 sec/step)
# INFO:tensorflow:global step 665: loss: 0.9552 (0.68 sec/step)
# INFO:tensorflow:global step 666: loss: 1.1115 (0.70 sec/step)
# INFO:tensorflow:global step 667: loss: 0.9690 (0.69 sec/step)
# INFO:tensorflow:global step 668: loss: 0.7540 (0.68 sec/step)
# INFO:tensorflow:global step 669: loss: 0.8646 (0.68 sec/step)
# INFO:tensorflow:global step 670: loss: 0.6918 (0.68 sec/step)
# INFO:tensorflow:global step 671: loss: 0.7815 (0.69 sec/step)
# INFO:tensorflow:global step 672: loss: 0.7859 (0.68 sec/step)
# INFO:tensorflow:global step 673: loss: 0.6972 (0.67 sec/step)
# INFO:tensorflow:global step 674: loss: 0.6844 (0.70 sec/step)
# INFO:tensorflow:global step 675: loss: 0.9247 (0.69 sec/step)
# INFO:tensorflow:global step 676: loss: 0.5677 (0.70 sec/step)
# INFO:tensorflow:global step 677: loss: 0.8731 (0.69 sec/step)
# INFO:tensorflow:global step 678: loss: 0.7870 (0.68 sec/step)
# INFO:tensorflow:global step 679: loss: 0.8317 (0.68 sec/step)
# INFO:tensorflow:global step 680: loss: 0.8070 (0.69 sec/step)
# INFO:tensorflow:global step 681: loss: 0.5579 (0.69 sec/step)
# INFO:tensorflow:global step 682: loss: 0.5503 (0.68 sec/step)
# INFO:tensorflow:global step 683: loss: 0.7296 (0.69 sec/step)
# INFO:tensorflow:global step 684: loss: 0.5915 (0.67 sec/step)
# INFO:tensorflow:global step 685: loss: 0.7946 (0.69 sec/step)
# INFO:tensorflow:global step 686: loss: 0.7827 (0.69 sec/step)
# INFO:tensorflow:global step 687: loss: 1.3643 (0.69 sec/step)
# INFO:tensorflow:global step 688: loss: 0.6204 (0.68 sec/step)
# INFO:tensorflow:global step 689: loss: 0.9195 (0.69 sec/step)
# INFO:tensorflow:global step 690: loss: 0.5804 (0.69 sec/step)
# INFO:tensorflow:global step 691: loss: 0.7165 (0.69 sec/step)
# ...
# INFO:tensorflow:global step 17673: loss: 0.4884 (0.70 sec/step)
# INFO:tensorflow:global step 17674: loss: 0.4918 (0.68 sec/step)
# INFO:tensorflow:global step 17675: loss: 0.9436 (0.69 sec/step)
# INFO:tensorflow:global step 17676: loss: 0.6394 (0.70 sec/step)
# INFO:tensorflow:global step 17677: loss: 0.4918 (0.69 sec/step)
# INFO:tensorflow:global step 17678: loss: 0.8200 (0.69 sec/step)
# INFO:tensorflow:global step 17679: loss: 0.4954 (0.70 sec/step)
# INFO:tensorflow:global step 17680: loss: 0.4902 (0.69 sec/step)
# INFO:tensorflow:global step 17681: loss: 0.4980 (0.70 sec/step)
# INFO:tensorflow:global step 17682: loss: 0.4873 (0.70 sec/step)
# INFO:tensorflow:global step 17683: loss: 0.4865 (0.70 sec/step)
# INFO:tensorflow:global step 17684: loss: 0.5130 (0.69 sec/step)
# INFO:tensorflow:global step 17685: loss: 0.4927 (0.70 sec/step)
# INFO:tensorflow:global step 17686: loss: 0.4940 (0.70 sec/step)
# INFO:tensorflow:global step 17687: loss: 0.5015 (0.70 sec/step)
# INFO:tensorflow:global step 17688: loss: 0.4929 (0.70 sec/step)
# INFO:tensorflow:global step 17689: loss: 0.5011 (0.69 sec/step)
# INFO:tensorflow:global step 17690: loss: 0.4899 (0.69 sec/step)
# INFO:tensorflow:global step 17691: loss: 0.5294 (0.72 sec/step)
# INFO:tensorflow:global step 17692: loss: 0.6027 (0.71 sec/step)
# INFO:tensorflow:global step 17693: loss: 0.5372 (0.70 sec/step)
# INFO:tensorflow:global step 17694: loss: 0.5990 (0.70 sec/step)
# INFO:tensorflow:global step 17695: loss: 0.4921 (0.69 sec/step)
# INFO:tensorflow:global step 17696: loss: 0.5310 (0.70 sec/step)
# INFO:tensorflow:global step 17697: loss: 0.7380 (0.70 sec/step)
# INFO:tensorflow:global step 17698: loss: 0.5171 (0.69 sec/step)
# INFO:tensorflow:global step 17699: loss: 0.5848 (0.70 sec/step)
# INFO:tensorflow:global step 17700: loss: 0.5167 (0.70 sec/step)
# INFO:tensorflow:global step 17701: loss: 0.5094 (0.68 sec/step)
# INFO:tensorflow:global step 17702: loss: 0.5000 (0.70 sec/step)
# INFO:tensorflow:global step 17703: loss: 0.5267 (0.71 sec/step)
# INFO:tensorflow:global step 17704: loss: 0.8350 (0.70 sec/step)
# INFO:tensorflow:global step 17705: loss: 0.4894 (0.70 sec/step)
# INFO:tensorflow:global step 17706: loss: 0.4938 (0.68 sec/step)
# INFO:tensorflow:global step 17707: loss: 0.5001 (0.70 sec/step)
# INFO:tensorflow:global step 17708: loss: 0.6451 (0.70 sec/step)
# INFO:tensorflow:global step 17709: loss: 0.4878 (0.70 sec/step)
# INFO:tensorflow:global step 17710: loss: 0.4894 (0.70 sec/step)
# INFO:tensorflow:global step 17711: loss: 0.6085 (0.71 sec/step)
# INFO:tensorflow:global step 17712: loss: 0.6715 (0.70 sec/step)
# INFO:tensorflow:global step 17713: loss: 0.8306 (0.70 sec/step)
# INFO:tensorflow:global step 17714: loss: 0.5680 (0.72 sec/step)
# INFO:tensorflow:global step 17715: loss: 0.4881 (0.70 sec/step)
# INFO:tensorflow:global step 17716: loss: 0.5016 (0.71 sec/step)
# INFO:tensorflow:global step 17717: loss: 0.4896 (0.70 sec/step)
# INFO:tensorflow:global step 17718: loss: 0.5116 (0.70 sec/step)
# INFO:tensorflow:global step 17719: loss: 0.5040 (0.72 sec/step)
# INFO:tensorflow:global step 17720: loss: 0.5821 (0.70 sec/step)
# INFO:tensorflow:global step 17721: loss: 0.4873 (0.70 sec/step)
# INFO:tensorflow:global step 17722: loss: 0.5493 (0.69 sec/step)
# INFO:tensorflow:global step 17723: loss: 0.4890 (0.70 sec/step)
# INFO:tensorflow:global step 17724: loss: 0.5098 (0.70 sec/step)
# INFO:tensorflow:global step 17725: loss: 0.4943 (0.71 sec/step)
# INFO:tensorflow:global step 17726: loss: 0.4921 (0.71 sec/step)
# INFO:tensorflow:global step 17727: loss: 0.6575 (0.69 sec/step)
# INFO:tensorflow:global step 17728: loss: 0.4914 (0.70 sec/step)
# INFO:tensorflow:global step 17729: loss: 0.4970 (0.71 sec/step)
# INFO:tensorflow:global step 17730: loss: 0.4928 (0.70 sec/step)
# INFO:tensorflow:global step 17731: loss: 0.8682 (0.71 sec/step)
# INFO:tensorflow:global step 17732: loss: 0.4960 (0.70 sec/step)
# INFO:tensorflow:global step 17733: loss: 0.4878 (0.69 sec/step)
# INFO:tensorflow:global step 17734: loss: 0.4921 (0.70 sec/step)
# INFO:tensorflow:global step 17735: loss: 0.6041 (0.69 sec/step)
# INFO:tensorflow:global step 17736: loss: 0.5176 (0.68 sec/step)
# INFO:tensorflow:global step 17737: loss: 0.5376 (0.71 sec/step)
# INFO:tensorflow:global step 17738: loss: 0.4866 (0.70 sec/step)
# INFO:tensorflow:global step 17739: loss: 0.7156 (0.71 sec/step)
# INFO:tensorflow:global step 17740: loss: 0.5138 (0.71 sec/step)
# INFO:tensorflow:global step 17741: loss: 0.7326 (0.70 sec/step)
# INFO:tensorflow:global step 17742: loss: 0.6259 (0.70 sec/step)
# INFO:tensorflow:global step 17743: loss: 0.5354 (0.70 sec/step)
# INFO:tensorflow:global step 17744: loss: 0.4864 (0.70 sec/step)
# INFO:tensorflow:global step 17745: loss: 0.6331 (0.69 sec/step)
# INFO:tensorflow:global step 17746: loss: 0.4873 (0.71 sec/step)
# INFO:tensorflow:global step 17747: loss: 0.6763 (0.68 sec/step)
# INFO:tensorflow:global step 17748: loss: 0.5054 (0.70 sec/step)
# INFO:tensorflow:global step 17749: loss: 0.4865 (0.69 sec/step)
# INFO:tensorflow:global step 17750: loss: 0.5990 (0.69 sec/step)
# INFO:tensorflow:global step 17751: loss: 0.4865 (0.70 sec/step)
# INFO:tensorflow:global step 17752: loss: 0.4931 (0.71 sec/step)
# INFO:tensorflow:global step 17753: loss: 0.4952 (0.69 sec/step)
# INFO:tensorflow:global step 17754: loss: 0.7121 (0.69 sec/step)
# INFO:tensorflow:global step 17755: loss: 0.4929 (0.70 sec/step)
# INFO:tensorflow:global step 17756: loss: 0.7252 (0.71 sec/step)
# INFO:tensorflow:global step 17757: loss: 0.4901 (0.70 sec/step)
# INFO:tensorflow:global step 17758: loss: 0.5359 (0.70 sec/step)
# INFO:tensorflow:global step 17759: loss: 0.5538 (0.70 sec/step)
# INFO:tensorflow:global step 17760: loss: 0.5494 (0.69 sec/step)
# INFO:tensorflow:global step 17761: loss: 0.5055 (0.71 sec/step)
# INFO:tensorflow:global step 17762: loss: 0.4887 (0.70 sec/step)
# INFO:tensorflow:global step 17763: loss: 0.5158 (0.70 sec/step)
# INFO:tensorflow:global step 17764: loss: 0.4921 (0.69 sec/step)
# INFO:tensorflow:global step 17765: loss: 0.7496 (0.69 sec/step)
# INFO:tensorflow:global step 17766: loss: 0.4942 (0.70 sec/step)
# INFO:tensorflow:global step 17767: loss: 0.5748 (0.70 sec/step)
# INFO:tensorflow:global step 17768: loss: 0.4996 (0.70 sec/step)
# INFO:tensorflow:global step 17769: loss: 0.5161 (0.70 sec/step)
# INFO:tensorflow:global step 17770: loss: 0.6268 (0.70 sec/step)
# INFO:tensorflow:global step 17771: loss: 0.4879 (0.70 sec/step)
# INFO:tensorflow:global step 17772: loss: 0.4973 (0.71 sec/step)
# INFO:tensorflow:global step 17773: loss: 0.5329 (0.71 sec/step)
# INFO:tensorflow:global step 17774: loss: 0.5540 (0.71 sec/step)
# INFO:tensorflow:global step 17775: loss: 0.5567 (0.70 sec/step)
# INFO:tensorflow:global step 17776: loss: 0.4935 (0.70 sec/step)
# INFO:tensorflow:global step 17777: loss: 0.6024 (0.70 sec/step)
# INFO:tensorflow:global step 17778: loss: 0.7380 (0.69 sec/step)
# INFO:tensorflow:global step 17779: loss: 0.4896 (0.69 sec/step)
# INFO:tensorflow:global step 17780: loss: 0.6084 (0.70 sec/step)
# INFO:tensorflow:global step 17781: loss: 0.5030 (0.70 sec/step)
# INFO:tensorflow:global step 17782: loss: 0.4924 (0.71 sec/step)
# INFO:tensorflow:global step 17783: loss: 0.5084 (0.70 sec/step)
# INFO:tensorflow:global step 17784: loss: 0.5596 (0.71 sec/step)
# INFO:tensorflow:global step 17785: loss: 0.5117 (0.70 sec/step)
# INFO:tensorflow:global step 17786: loss: 0.4900 (0.71 sec/step)
# INFO:tensorflow:global step 17787: loss: 0.4866 (0.73 sec/step)
# INFO:tensorflow:global step 17788: loss: 0.4976 (0.70 sec/step)
# INFO:tensorflow:global step 17789: loss: 0.5149 (0.71 sec/step)
# INFO:tensorflow:global step 17790: loss: 0.4870 (0.70 sec/step)
# INFO:tensorflow:global step 17791: loss: 0.4907 (0.70 sec/step)
# INFO:tensorflow:global step 17792: loss: 1.1280 (0.69 sec/step)
# INFO:tensorflow:global step 17793: loss: 0.6359 (0.71 sec/step)
# INFO:tensorflow:global step 17794: loss: 0.5620 (0.70 sec/step)
# INFO:tensorflow:global step 17795: loss: 0.5517 (0.71 sec/step)
# INFO:tensorflow:global step 17796: loss: 0.4872 (0.71 sec/step)
# INFO:tensorflow:global step 17797: loss: 0.4956 (0.70 sec/step)
# INFO:tensorflow:global step 17798: loss: 0.8922 (0.71 sec/step)
# INFO:tensorflow:global step 17799: loss: 0.5312 (0.70 sec/step)
# INFO:tensorflow:global step 17800: loss: 0.7972 (0.69 sec/step)
# INFO:tensorflow:global step 17801: loss: 0.4924 (0.70 sec/step)
# INFO:tensorflow:global step 17802: loss: 0.7810 (0.69 sec/step)
# INFO:tensorflow:global step 17803: loss: 0.4999 (0.70 sec/step)
# INFO:tensorflow:global step 17804: loss: 0.5480 (0.71 sec/step)
# INFO:tensorflow:global step 17805: loss: 0.4994 (0.70 sec/step)
# INFO:tensorflow:global step 17806: loss: 0.5719 (0.70 sec/step)
# INFO:tensorflow:global step 17807: loss: 0.4896 (0.70 sec/step)
# INFO:tensorflow:global step 17808: loss: 0.4872 (0.70 sec/step)
# INFO:tensorflow:global step 17809: loss: 0.4863 (0.70 sec/step)
# INFO:tensorflow:global step 17810: loss: 0.4874 (0.69 sec/step)
# INFO:tensorflow:global step 17811: loss: 0.4870 (0.69 sec/step)
# INFO:tensorflow:global step 17812: loss: 0.6102 (0.70 sec/step)
# INFO:tensorflow:global step 17813: loss: 0.5113 (0.71 sec/step)
# INFO:tensorflow:global step 17814: loss: 0.4876 (0.70 sec/step)
# INFO:tensorflow:global step 17815: loss: 0.5266 (0.70 sec/step)
# INFO:tensorflow:global step 17816: loss: 0.7931 (0.69 sec/step)
# INFO:tensorflow:global step 17817: loss: 0.5725 (0.69 sec/step)
# INFO:tensorflow:global step 17818: loss: 0.5039 (0.71 sec/step)
# INFO:tensorflow:global step 17819: loss: 0.6422 (0.70 sec/step)
# INFO:tensorflow:global step 17820: loss: 0.4883 (0.70 sec/step)
# INFO:tensorflow:global step 17821: loss: 0.4901 (0.69 sec/step)
# INFO:tensorflow:global step 17822: loss: 0.5924 (0.69 sec/step)
# INFO:tensorflow:global step 17823: loss: 0.5514 (0.70 sec/step)
# INFO:tensorflow:global step 17824: loss: 0.5887 (0.71 sec/step)
# INFO:tensorflow:global step 17825: loss: 0.4884 (0.71 sec/step)
# INFO:tensorflow:global step 17826: loss: 0.7460 (0.71 sec/step)
# INFO:tensorflow:global step 17827: loss: 0.4941 (0.70 sec/step)
# INFO:tensorflow:global step 17828: loss: 0.5111 (0.70 sec/step)
# INFO:tensorflow:global step 17829: loss: 0.4876 (0.70 sec/step)
# INFO:tensorflow:global step 17830: loss: 0.5189 (0.70 sec/step)
# INFO:tensorflow:global step 17831: loss: 0.4952 (0.70 sec/step)
# INFO:tensorflow:global step 17832: loss: 0.5087 (0.72 sec/step)
# INFO:tensorflow:global step 17833: loss: 0.5738 (0.70 sec/step)
# INFO:tensorflow:global step 17834: loss: 0.5672 (0.71 sec/step)
# INFO:tensorflow:global step 17835: loss: 0.5345 (0.69 sec/step)
# INFO:tensorflow:global step 17836: loss: 0.6041 (0.69 sec/step)
# INFO:tensorflow:global step 17837: loss: 0.5127 (0.68 sec/step)
# INFO:tensorflow:global step 17838: loss: 0.6726 (0.70 sec/step)
# INFO:tensorflow:global step 17839: loss: 0.4946 (0.70 sec/step)
# INFO:tensorflow:global step 17840: loss: 0.4979 (0.70 sec/step)
# INFO:tensorflow:global step 17841: loss: 0.4864 (0.71 sec/step)
# INFO:tensorflow:global step 17842: loss: 0.7338 (0.70 sec/step)
# INFO:tensorflow:global step 17843: loss: 0.5069 (0.71 sec/step)
# INFO:tensorflow:global step 17844: loss: 0.4902 (0.68 sec/step)
# INFO:tensorflow:global step 17845: loss: 0.5105 (0.70 sec/step)
# INFO:tensorflow:global step 17846: loss: 0.4934 (0.70 sec/step)
# INFO:tensorflow:global step 17847: loss: 0.4908 (0.70 sec/step)
# INFO:tensorflow:global step 17848: loss: 0.4896 (0.70 sec/step)
# INFO:tensorflow:global step 17849: loss: 0.4931 (0.71 sec/step)
# INFO:tensorflow:global step 17850: loss: 0.4886 (0.69 sec/step)
# INFO:tensorflow:global step 17851: loss: 0.5144 (0.71 sec/step)
# INFO:tensorflow:global step 17852: loss: 0.8627 (0.71 sec/step)
# INFO:tensorflow:global step 17853: loss: 0.6638 (0.69 sec/step)
# INFO:tensorflow:global step 17854: loss: 0.4924 (0.70 sec/step)
# INFO:tensorflow:global step 17855: loss: 0.5206 (0.70 sec/step)
# INFO:tensorflow:global step 17856: loss: 0.4873 (0.68 sec/step)
# INFO:tensorflow:global step 17857: loss: 0.4977 (0.71 sec/step)
# INFO:tensorflow:global step 17858: loss: 0.4884 (0.69 sec/step)
# INFO:tensorflow:global step 17859: loss: 0.4945 (0.71 sec/step)
# INFO:tensorflow:global step 17860: loss: 0.4927 (0.70 sec/step)
# INFO:tensorflow:global step 17861: loss: 0.4937 (0.70 sec/step)
# INFO:tensorflow:global step 17862: loss: 0.5469 (0.71 sec/step)
# INFO:tensorflow:global step 17863: loss: 0.4879 (0.70 sec/step)
# INFO:tensorflow:global step 17864: loss: 0.5362 (0.69 sec/step)
# INFO:tensorflow:global step 17865: loss: 0.4903 (0.71 sec/step)
# INFO:tensorflow:global step 17866: loss: 0.4967 (0.70 sec/step)
# INFO:tensorflow:global step 17867: loss: 0.4940 (0.68 sec/step)
# INFO:tensorflow:global step 17868: loss: 0.4864 (0.70 sec/step)
# INFO:tensorflow:global step 17869: loss: 0.5002 (0.69 sec/step)
# INFO:tensorflow:global step 17870: loss: 0.6312 (0.71 sec/step)
# INFO:tensorflow:global step 17871: loss: 0.4886 (0.70 sec/step)
# INFO:tensorflow:global step 17872: loss: 0.4946 (0.70 sec/step)
# INFO:tensorflow:global step 17873: loss: 0.4882 (0.70 sec/step)
# INFO:tensorflow:global step 17874: loss: 0.5556 (0.69 sec/step)
# INFO:tensorflow:global step 17875: loss: 0.6545 (0.70 sec/step)
# INFO:tensorflow:global step 17876: loss: 0.4870 (0.71 sec/step)
# INFO:tensorflow:global step 17877: loss: 0.4925 (0.71 sec/step)
# INFO:tensorflow:global step 17878: loss: 0.4960 (0.71 sec/step)
# INFO:tensorflow:global step 17879: loss: 0.6724 (0.70 sec/step)
# INFO:tensorflow:global step 17880: loss: 0.5190 (0.71 sec/step)
# INFO:tensorflow:global step 17881: loss: 0.5951 (0.71 sec/step)
# INFO:tensorflow:global step 17882: loss: 0.4943 (0.70 sec/step)
# INFO:tensorflow:global step 17883: loss: 0.5566 (0.71 sec/step)
# INFO:tensorflow:global step 17884: loss: 0.6578 (0.70 sec/step)
# INFO:tensorflow:global step 17885: loss: 0.4877 (0.70 sec/step)
# INFO:tensorflow:global step 17886: loss: 0.5115 (0.71 sec/step)
# INFO:tensorflow:global step 17887: loss: 0.6457 (0.70 sec/step)
# INFO:tensorflow:global step 17888: loss: 0.4934 (0.70 sec/step)
# INFO:tensorflow:global step 17889: loss: 0.4874 (0.70 sec/step)
# INFO:tensorflow:global step 17890: loss: 0.7029 (0.72 sec/step)
# INFO:tensorflow:global step 17891: loss: 0.4966 (0.71 sec/step)
# INFO:tensorflow:global step 17892: loss: 0.5498 (0.71 sec/step)
# INFO:tensorflow:global step 17893: loss: 0.4869 (0.71 sec/step)
# INFO:tensorflow:global step 17894: loss: 0.4867 (0.71 sec/step)
# INFO:tensorflow:global step 17895: loss: 0.4863 (0.69 sec/step)
# INFO:tensorflow:global step 17896: loss: 0.4904 (0.70 sec/step)
# INFO:tensorflow:global step 17897: loss: 0.5789 (0.70 sec/step)
# INFO:tensorflow:global step 17898: loss: 0.5078 (0.70 sec/step)
# INFO:tensorflow:global step 17899: loss: 0.5096 (0.71 sec/step)
# INFO:tensorflow:global step 17900: loss: 0.5228 (0.70 sec/step)
# INFO:tensorflow:global step 17901: loss: 0.4864 (0.69 sec/step)
# INFO:tensorflow:global step 17902: loss: 0.5046 (0.70 sec/step)
# INFO:tensorflow:global step 17903: loss: 0.6641 (0.70 sec/step)
# INFO:tensorflow:global step 17904: loss: 0.4896 (0.70 sec/step)
# INFO:tensorflow:global step 17905: loss: 0.6882 (0.70 sec/step)
# INFO:tensorflow:global step 17906: loss: 0.5095 (0.71 sec/step)
# INFO:tensorflow:global step 17907: loss: 0.4905 (0.71 sec/step)
# INFO:tensorflow:global step 17908: loss: 0.4918 (0.69 sec/step)
# INFO:tensorflow:global step 17909: loss: 0.6015 (0.70 sec/step)
# INFO:tensorflow:global step 17910: loss: 0.4959 (0.70 sec/step)
# INFO:tensorflow:global step 17911: loss: 0.4916 (0.72 sec/step)
# INFO:tensorflow:global step 17912: loss: 0.4918 (0.70 sec/step)
# INFO:tensorflow:global step 17913: loss: 0.7742 (0.70 sec/step)
# INFO:tensorflow:global step 17914: loss: 0.4936 (0.71 sec/step)
# INFO:tensorflow:global step 17915: loss: 0.4875 (0.71 sec/step)
# INFO:tensorflow:global step 17916: loss: 0.4912 (0.71 sec/step)
# INFO:tensorflow:global step 17917: loss: 0.4875 (0.71 sec/step)
# INFO:tensorflow:global step 17918: loss: 0.5902 (0.70 sec/step)
# INFO:tensorflow:global step 17919: loss: 0.5014 (0.71 sec/step)
# INFO:tensorflow:Final Loss: 0.50136447
# INFO:tensorflow:Final Accuracy: 0.9668694
# INFO:tensorflow:Finished training! Saving model to disk now.
